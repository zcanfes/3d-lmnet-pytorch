# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# We assume you uploaded the exercise folder in root Google Drive folder
# !cp -r /content/drive/MyDrive/3d-lmnet-pytorch 3d-lmnet-pytorch
os.chdir('/content/drive/MyDrive/3d-lmnet-pytorch')
print('Installing requirements')
# !pip install -r requirements.txt

# Make sure you restart runtime when directed by Colab
# Out:
# Mounted at /content/drive
# Installing requirements
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jupyter>=1.0.0
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting K3D>=2.9.4
#   Downloading k3d-2.15.2-py3-none-any.whl (23.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.0/23.0 MB 64.5 MB/s eta 0:00:00
# Collecting matplotlib>=3.4.1
#   Downloading matplotlib-3.6.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 107.6 MB/s eta 0:00:00
# Collecting trimesh>=3.9.14
#   Downloading trimesh-3.18.1-py3-none-any.whl (670 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.9/670.9 KB 56.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 5)) (1.13.1+cu116)
# Collecting pytorch-lightning>=1.2.8
#   Downloading pytorch_lightning-1.9.0-py3-none-any.whl (825 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 KB 47.4 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image>=0.18.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 7)) (0.18.3)
# Collecting pyrender>=0.1.43
#   Downloading pyrender-0.1.45-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.7 MB/s eta 0:00:00
# Collecting moviepy>=1.0.3
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 KB 31.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pillow>=7.2.0
#   Downloading Pillow-9.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 99.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 11)) (4.64.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 12)) (1.7.3)
# Requirement already satisfied: numpy>=1.19.4 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 13)) (1.21.6)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.8/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 1)) (5.3.4)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.8/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 1)) (5.6.1)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.8/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.8/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 1)) (5.7.16)
# Collecting qtconsole
#   Downloading qtconsole-5.4.0-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.0/121.0 KB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 1)) (7.7.1)
# Collecting traittypes
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.8/dist-packages (from K3D>=2.9.4->-r requirements.txt (line 2)) (1.0.4)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.8/dist-packages (from K3D>=2.9.4->-r requirements.txt (line 2)) (5.7.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4.1->-r requirements.txt (line 3)) (0.11.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 69.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4.1->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4.1->-r requirements.txt (line 3)) (3.0.9)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4.1->-r requirements.txt (line 3)) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4.1->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.8.1->-r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (6.0)
# Collecting lightning-utilities>=0.4.2
#   Downloading lightning_utilities-0.5.0-py3-none-any.whl (18 kB)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.0-py3-none-any.whl (512 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.4/512.4 KB 47.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (2022.11.0)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.18.1->-r requirements.txt (line 7)) (3.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.18.1->-r requirements.txt (line 7)) (1.4.1)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.18.1->-r requirements.txt (line 7)) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.18.1->-r requirements.txt (line 7)) (2022.10.10)
# Collecting freetype-py
#   Downloading freetype_py-2.3.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (978 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.9/978.9 KB 53.4 MB/s eta 0:00:00
# Collecting pyglet>=1.4.10
#   Downloading pyglet-2.0.3-py3-none-any.whl (968 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 968.6/968.6 KB 74.2 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from pyrender>=0.1.43->-r requirements.txt (line 8)) (1.15.0)
# Collecting PyOpenGL==3.1.0
#   Downloading PyOpenGL-3.1.0.zip (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 88.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.8/dist-packages (from moviepy>=1.0.3->-r requirements.txt (line 9)) (4.4.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from moviepy>=1.0.3->-r requirements.txt (line 9)) (2.25.1)
# Collecting proglog<=1.0.0
#   Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Collecting imageio_ffmpeg>=0.2.0
#   Downloading imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 63.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (3.8.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (7.9.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (3.0.5)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel->jupyter>=1.0.0->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel->jupyter>=1.0.0->-r requirements.txt (line 1)) (6.1.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.3->-r requirements.txt (line 9)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.3->-r requirements.txt (line 9)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.3->-r requirements.txt (line 9)) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.3->-r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from jupyter-console->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from jupyter-console->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.0.10)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.4)
# Requirement already satisfied: jinja2>=2.4 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.11.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nbformat>=4.4 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (5.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (5.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.13.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.15.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 1)) (23.2.1)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 KB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (6.0.4)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (57.4.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.2.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 87.1 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2>=2.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.6.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat>=4.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat>=4.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (4.3.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.8/dist-packages (from terminado>=0.8.1->notebook->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (5.10.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.19.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (3.11.0)
# Building wheels for collected packages: PyOpenGL, moviepy
#   Building wheel for PyOpenGL (setup.py) ... done
#   Created wheel for PyOpenGL: filename=PyOpenGL-3.1.0-py3-none-any.whl size=1745210 sha256=d646ceb35ff967b3c1215f14af2615022adf799fae685536510d2e22a5290a3d
#   Stored in directory: /root/.cache/pip/wheels/85/ff/54/41f30bb227befd3dde302de39f9ba042589e8b4f93723107f2
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110742 sha256=6d5d9f28a75eec250195212cf1ff9fce89b58a7a372db5cbdc6dc6bf2d91d3f2
#   Stored in directory: /root/.cache/pip/wheels/e4/a4/db/0368d3a04033da662e13926594b3a8cf1aa4ffeefe570cfac1
# Successfully built PyOpenGL moviepy
# Installing collected packages: PyOpenGL, pyglet, trimesh, traittypes, proglog, pillow, jedi, imageio_ffmpeg, freetype-py, fonttools, contourpy, torchmetrics, qtpy, matplotlib, lightning-utilities, pyrender, moviepy, qtconsole, pytorch-lightning, K3D, jupyter
#   Attempting uninstall: PyOpenGL
#     Found existing installation: PyOpenGL 3.1.6
#     Uninstalling PyOpenGL-3.1.6:
#       Successfully uninstalled PyOpenGL-3.1.6
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: moviepy
#     Found existing installation: moviepy 0.2.3.5
#     Uninstalling moviepy-0.2.3.5:
#       Successfully uninstalled moviepy-0.2.3.5
# Successfully installed K3D-2.15.2 PyOpenGL-3.1.0 contourpy-1.0.7 fonttools-4.38.0 freetype-py-2.3.0 imageio_ffmpeg-0.4.8 jedi-0.18.2 jupyter-1.0.0 lightning-utilities-0.5.0 matplotlib-3.6.3 moviepy-1.0.3 pillow-9.4.0 proglog-0.1.10 pyglet-2.0.3 pyrender-0.1.45 pytorch-lightning-1.9.0 qtconsole-5.4.0 qtpy-2.3.0 torchmetrics-0.11.0 traittypes-0.2.1 trimesh-3.18.1

# %%
import os
import sys
import torch
os.chdir('/content/3d-lmnet-pytorch/3d-lmnet-pytorch')
sys.path.insert(1, "/content/3d-lmnet-pytorch/3d-lmnet-pytorch")
print('CUDA availability:', torch.cuda.is_available())
# Out:
# CUDA availability: True

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import numpy as np
import matplotlib as plt
import k3d
import trimesh
import torch
import skimage

# %%
torch.cuda.is_available()
need_pytorch3d=False
try:
    import pytorch3d
except ModuleNotFoundError:
    need_pytorch3d=True
if need_pytorch3d:
    if sys.platform.startswith("linux"):
        # We try to install PyTorch3D via a released wheel.
        pyt_version_str=torch.__version__.split("+")[0].replace(".", "")
        version_str="".join([
            f"py3{sys.version_info.minor}_cu",
            torch.version.cuda.replace(".",""),
            f"_pyt{pyt_version_str}"
        ])
        # !pip install pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/{version_str}/download.html
    else:
        # We try to install PyTorch3D from source.
        # !curl -LO https://github.com/NVIDIA/cub/archive/1.10.0.tar.gz
        # !tar xzf 1.10.0.tar.gz
        os.environ["CUB_HOME"] = os.getcwd() + "/cub-1.10.0"
        # !pip install 'git+https://github.com/facebookresearch/pytorch3d.git@stable'

# %% [markdown]
# ## ShapeNet Terms and Conditions
#
# In order to be able to use the data, we agree the below terms and conditions:
#
# 1. Researcher shall use the Database only for non-commercial research and educational purposes.
# 2. Princeton University and Stanford University make no representations or warranties regarding the Database, including but not limited to warranties of non-infringement or fitness for a particular purpose.
# 3. Researcher accepts full responsibility for his or her use of the Database and shall defend and indemnify Princeton University and Stanford University, including their employees, Trustees, officers and agents, against any and all claims arising from Researcher's use of the Database, including but not limited to Researcher's use of any copies of copyrighted 3D models that he or she may create from the Database.
# 4. Researcher may provide research associates and colleagues with access to the Database provided that they first agree to be bound by these terms and conditions.
# 5. Princeton University and Stanford University reserve the right to terminate Researcher's access to the Database at any time.
# 6. If Researcher is employed by a for-profit, commercial entity, Researcher's employer shall also be bound by these terms and conditions, and Researcher hereby represents that he or she is fully authorized to enter into this agreement on behalf of such employer.
# 7. The law of the State of New Jersey shall apply to all disputes under this agreement.

# %% [markdown]
# ### Unzip ShapeNet pointcloud zip

# %%
# !unzip -q ./data/ShapeNet_pointclouds.zip -d ./data

# %% [markdown]
# ### Download 2D images

# %%
# !wget http://cvgl.stanford.edu/data2/ShapeNetRendering.tgz -P ./data
# Out:
# --2023-01-18 21:27:09--  http://cvgl.stanford.edu/data2/ShapeNetRendering.tgz
# Resolving cvgl.stanford.edu (cvgl.stanford.edu)... 171.64.64.64
# Connecting to cvgl.stanford.edu (cvgl.stanford.edu)|171.64.64.64|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cvgl.stanford.edu/data2/ShapeNetRendering.tgz [following]
# --2023-01-18 21:27:09--  https://cvgl.stanford.edu/data2/ShapeNetRendering.tgz
# Connecting to cvgl.stanford.edu (cvgl.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12318245442 (11G) [application/x-gzip]
# Saving to: ‘./data/ShapeNetRendering.tgz’
#
# ShapeNetRendering.t 100%[===================>]  11.47G  19.8MB/s    in 12m 42s
#
# 2023-01-18 21:39:52 (15.4 MB/s) - ‘./data/ShapeNetRendering.tgz’ saved [12318245442/12318245442]

# %%
# !tar -xf ./data/ShapeNetRendering.tgz -C ./data
#!rm /content/term-project/data/ShapeNetRendering.tgz

# %% [markdown]
# ### Construct ShapeNet dataset

# %%
from data.shapenet import ShapeNet

# Create a dataset with train split
train_dataset = ShapeNet('train')
val_dataset = ShapeNet('valid')
#overfit_dataset = ShapeNet('overfit')
test_dataset = ShapeNet('test')

# Get length, which is a call to __len__ function
print(f'Length of train set: {len(train_dataset)}') 
# Get length, which is a call to __len__ function
print(f'Length of val set: {len(val_dataset)}') 
# Get length, which is a call to __len__ function
print(f'Length of test set: {len(test_dataset)}')
# Out:
# Length of train set: 26271
# Length of val set: 8758
# Length of test set: 8755

# %%
from skimage.measure import marching_cubes

train_sample = train_dataset[1]
print(f'Input images: {train_sample["img"].shape}')  
print(f'Input point cloud: {train_sample["point"].shape}')
# Out:
# Input images: (3, 128, 128)
# Input point cloud: (2048, 3)

# %% [markdown]
# ### Print output shape of the 2D Encoder model (both variational and normal versions)

# %%
from model.model_2d import ImageEncoder
from torchsummary import summary

model2d_variational=ImageEncoder("variational",128)
model2d_variational.cuda()
input_tensor = torch.randn(1,3,128,128)
input_tensor=input_tensor.cuda()
print("input size:",input_tensor.size())


mu,std = model2d_variational(input_tensor)
print("Mu size:",mu.size(),"Std size:",std.size())
summary(model2d_variational,(3,128,128))
model2d_normal=ImageEncoder("normal",128)
model2d_normal.cuda()
latent=model2d_normal(input_tensor)
print("Latent shape:",latent.size())
# Out:
# input size: torch.Size([1, 3, 128, 128])
# Mu size: torch.Size([1, 128]) Std size: torch.Size([1, 128])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 128, 128]             896
#               ReLU-2         [-1, 32, 128, 128]               0
#             Conv2d-3         [-1, 32, 128, 128]           9,248
#               ReLU-4         [-1, 32, 128, 128]               0
#             Conv2d-5           [-1, 64, 63, 63]          18,496
#               ReLU-6           [-1, 64, 63, 63]               0
#             Conv2d-7           [-1, 64, 63, 63]          36,928
#               ReLU-8           [-1, 64, 63, 63]               0
#             Conv2d-9           [-1, 64, 63, 63]          36,928
#              ReLU-10           [-1, 64, 63, 63]               0
#            Conv2d-11          [-1, 128, 31, 31]          73,856
#              ReLU-12          [-1, 128, 31, 31]               0
#            Conv2d-13          [-1, 128, 31, 31]         147,584
#              ReLU-14          [-1, 128, 31, 31]               0
#            Conv2d-15          [-1, 128, 31, 31]         147,584
#              ReLU-16          [-1, 128, 31, 31]               0
#            Conv2d-17          [-1, 256, 15, 15]         295,168
#              ReLU-18          [-1, 256, 15, 15]               0
#            Conv2d-19          [-1, 256, 15, 15]         590,080
#              ReLU-20          [-1, 256, 15, 15]               0
#            Conv2d-21          [-1, 256, 15, 15]         590,080
#              ReLU-22          [-1, 256, 15, 15]               0
#            Conv2d-23            [-1, 512, 7, 7]       1,180,160
#              ReLU-24            [-1, 512, 7, 7]               0
#            Conv2d-25            [-1, 512, 7, 7]       2,359,808
#              ReLU-26            [-1, 512, 7, 7]               0
#            Conv2d-27            [-1, 512, 7, 7]       2,359,808
#              ReLU-28            [-1, 512, 7, 7]               0
#            Conv2d-29            [-1, 512, 7, 7]       2,359,808
#              ReLU-30            [-1, 512, 7, 7]               0
#            Conv2d-31            [-1, 512, 2, 2]       6,554,112
#            Linear-32                  [-1, 128]         262,272
#            Linear-33                  [-1, 128]         262,272
# ================================================================
# Total params: 17,285,088
# Trainable params: 17,285,088
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 37.44
# Params size (MB): 65.94
# Estimated Total Size (MB): 103.57
# ----------------------------------------------------------------
# Latent shape: torch.Size([1, 128])

# %% [markdown]
# ### Train 2D Encoder model to match the predicted latent space to the output of 3D Encoder of pointclouds

# %% [markdown]
# Normal, L1 loss

# %%
from training import train_2d_to_3d

generalization_config = {
    'experiment_name': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/2d_logs/normal/L1',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'bottleneck': 512,
    "cat":13,
    'batch_size': 32,
    "loss_criterion":"L1",
    "final_layer":"normal",
    "3d_encoder_path":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/additional_epoches/model_epoch_500.pth",
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    'max_epochs': 30,  
    'print_every_n': 5,
    'validate_every_n': 5,
    "autoencoder_bottleneck":512,
    "autoencoder_hidden_size":256,
    "autoencoder_output_size":2048*3,
    "alpha":None,
    "penalty_angle":None,
    "lambda":None


}

train_2d_to_3d.main(generalization_config)
# Out:
# Using device: cuda:0
#  initial input 512 initial hidden 256 initial output 6144
# Epoch 0/30 with iteration 100/19703: CD loss is 0.038367386907339096.
# Epoch 0/30 with iteration 200/19703: CD loss is 0.03756820783019066.
# Epoch 0/30 with iteration 300/19703: CD loss is 0.03737949579954147.
# Epoch 0/30 with iteration 400/19703: CD loss is 0.03532445430755615.
# Epoch 0/30 with iteration 500/19703: CD loss is 0.03256985917687416.
# Epoch 0/30 with iteration 600/19703: CD loss is 0.033990584313869476.
# Epoch 0/30 with iteration 700/19703: CD loss is 0.02871124818921089.
# Epoch 0/30 with iteration 800/19703: CD loss is 0.032691117376089096.
# Epoch 0/30 with iteration 900/19703: CD loss is 0.02899467572569847.
# Epoch 0/30 with iteration 1000/19703: CD loss is 0.032819584012031555.
# Epoch 0/30 with iteration 1100/19703: CD loss is 0.028395535424351692.
# Epoch 0/30 with iteration 1200/19703: CD loss is 0.03431117534637451.
# Epoch 0/30 with iteration 1300/19703: CD loss is 0.030192317441105843.
# Epoch 0/30 with iteration 1400/19703: CD loss is 0.027028117328882217.
# Epoch 0/30 with iteration 1500/19703: CD loss is 0.03137972950935364.
# Epoch 0/30 with iteration 1600/19703: CD loss is 0.02812516689300537.
# Epoch 0/30 with iteration 1700/19703: CD loss is 0.025791475549340248.
# Epoch 0/30 with iteration 1800/19703: CD loss is 0.02790728583931923.
# Epoch 0/30 with iteration 1900/19703: CD loss is 0.03035859949886799.
# Epoch 0/30 with iteration 2000/19703: CD loss is 0.028980392962694168.
# Epoch 0/30 with iteration 2100/19703: CD loss is 0.025100059807300568.
# Epoch 0/30 with iteration 2200/19703: CD loss is 0.02983260527253151.
# Epoch 0/30 with iteration 2300/19703: CD loss is 0.029278244823217392.
# Epoch 0/30 with iteration 2400/19703: CD loss is 0.029085533693432808.
# Epoch 0/30 with iteration 2500/19703: CD loss is 0.02559562772512436.
# Epoch 0/30 with iteration 2600/19703: CD loss is 0.02661087177693844.
# Epoch 0/30 with iteration 2700/19703: CD loss is 0.028650347143411636.
# Epoch 0/30 with iteration 2800/19703: CD loss is 0.02635108307003975.
# Epoch 0/30 with iteration 2900/19703: CD loss is 0.02787144109606743.
# Epoch 0/30 with iteration 3000/19703: CD loss is 0.027901578694581985.
# Epoch 0/30 with iteration 3100/19703: CD loss is 0.026910293847322464.
# Epoch 0/30 with iteration 3200/19703: CD loss is 0.026198020204901695.
# Epoch 0/30 with iteration 3300/19703: CD loss is 0.02799168974161148.
# Epoch 0/30 with iteration 3400/19703: CD loss is 0.028412053361535072.
# Epoch 0/30 with iteration 3500/19703: CD loss is 0.024684952571988106.
# Epoch 0/30 with iteration 3600/19703: CD loss is 0.02863069251179695.
# Epoch 0/30 with iteration 3700/19703: CD loss is 0.02851400524377823.
# Epoch 0/30 with iteration 3800/19703: CD loss is 0.025783736258745193.
# Epoch 0/30 with iteration 3900/19703: CD loss is 0.02415570244193077.
# Epoch 0/30 with iteration 4000/19703: CD loss is 0.026065150275826454.
# Epoch 0/30 with iteration 4100/19703: CD loss is 0.02499576285481453.
# Epoch 0/30 with iteration 4200/19703: CD loss is 0.026241090148687363.
# Epoch 0/30 with iteration 4300/19703: CD loss is 0.027809564024209976.
# Epoch 0/30 with iteration 4400/19703: CD loss is 0.02525373175740242.
# Epoch 0/30 with iteration 4500/19703: CD loss is 0.02919710800051689.
# Epoch 0/30 with iteration 4600/19703: CD loss is 0.027696797624230385.
# Epoch 0/30 with iteration 4700/19703: CD loss is 0.02665141597390175.
# Epoch 0/30 with iteration 4800/19703: CD loss is 0.027953030541539192.
# Epoch 0/30 with iteration 4900/19703: CD loss is 0.024840068072080612.
# Epoch 0/30 with iteration 5000/19703: CD loss is 0.023946965113282204.
# Epoch 0/30 with iteration 5100/19703: CD loss is 0.023531388491392136.
# Epoch 0/30 with iteration 5200/19703: CD loss is 0.027877308428287506.
# Epoch 0/30 with iteration 5300/19703: CD loss is 0.027650659903883934.
# Epoch 0/30 with iteration 5400/19703: CD loss is 0.0247274711728096.
# Epoch 0/30 with iteration 5500/19703: CD loss is 0.02693656086921692.
# Epoch 0/30 with iteration 5600/19703: CD loss is 0.0269406009465456.
# Epoch 0/30 with iteration 5700/19703: CD loss is 0.02750229649245739.
# Epoch 0/30 with iteration 5800/19703: CD loss is 0.02718355692923069.
# Epoch 0/30 with iteration 5900/19703: CD loss is 0.024316247552633286.
# Epoch 0/30 with iteration 6000/19703: CD loss is 0.02545423060655594.
# Epoch 0/30 with iteration 6100/19703: CD loss is 0.027729209512472153.
# Epoch 0/30 with iteration 6200/19703: CD loss is 0.023707497864961624.
# Epoch 0/30 with iteration 6300/19703: CD loss is 0.026368172839283943.
# Epoch 0/30 with iteration 6400/19703: CD loss is 0.024982552975416183.
# Epoch 0/30 with iteration 6500/19703: CD loss is 0.02467779815196991.
# Epoch 0/30 with iteration 6600/19703: CD loss is 0.02448112517595291.
# Epoch 0/30 with iteration 6700/19703: CD loss is 0.025747593492269516.
# Epoch 0/30 with iteration 6800/19703: CD loss is 0.026670660823583603.
# Epoch 0/30 with iteration 6900/19703: CD loss is 0.03048057109117508.
# Epoch 0/30 with iteration 7000/19703: CD loss is 0.02387198805809021.
# Epoch 0/30 with iteration 7100/19703: CD loss is 0.025668498128652573.
# Epoch 0/30 with iteration 7200/19703: CD loss is 0.026855871081352234.
# Epoch 0/30 with iteration 7300/19703: CD loss is 0.023910440504550934.
# Epoch 0/30 with iteration 7400/19703: CD loss is 0.024454567581415176.
# Epoch 0/30 with iteration 7500/19703: CD loss is 0.020765986293554306.
# Epoch 0/30 with iteration 7600/19703: CD loss is 0.026133069768548012.
# Epoch 0/30 with iteration 7700/19703: CD loss is 0.02554965764284134.
# Epoch 0/30 with iteration 7800/19703: CD loss is 0.024042073637247086.
# Epoch 0/30 with iteration 7900/19703: CD loss is 0.023454420268535614.
# Epoch 0/30 with iteration 8000/19703: CD loss is 0.025175340473651886.
# Epoch 0/30 with iteration 8100/19703: CD loss is 0.023005284368991852.
# Epoch 0/30 with iteration 8200/19703: CD loss is 0.027315448969602585.
# Epoch 0/30 with iteration 8300/19703: CD loss is 0.02688709832727909.
# Epoch 0/30 with iteration 8400/19703: CD loss is 0.02749178744852543.
# Epoch 0/30 with iteration 8500/19703: CD loss is 0.023680098354816437.
# Epoch 0/30 with iteration 8600/19703: CD loss is 0.02528253197669983.
# Epoch 0/30 with iteration 8700/19703: CD loss is 0.027351411059498787.
# Epoch 0/30 with iteration 8800/19703: CD loss is 0.026042133569717407.
# Epoch 0/30 with iteration 8900/19703: CD loss is 0.025096427649259567.
# Epoch 0/30 with iteration 9000/19703: CD loss is 0.022907640784978867.
# Epoch 0/30 with iteration 9100/19703: CD loss is 0.023705611005425453.
# Epoch 0/30 with iteration 9200/19703: CD loss is 0.026883399114012718.
# Epoch 0/30 with iteration 9300/19703: CD loss is 0.02502753585577011.
# Epoch 0/30 with iteration 9400/19703: CD loss is 0.024343958124518394.
# Epoch 0/30 with iteration 9500/19703: CD loss is 0.02409088984131813.
# Epoch 0/30 with iteration 9600/19703: CD loss is 0.027553915977478027.
# Epoch 0/30 with iteration 9700/19703: CD loss is 0.022998571395874023.
# Epoch 0/30 with iteration 9800/19703: CD loss is 0.023369066417217255.
# Epoch 0/30 with iteration 9900/19703: CD loss is 0.02682025544345379.
# Epoch 0/30 with iteration 10000/19703: CD loss is 0.023864980787038803.
# Epoch 0/30 with iteration 10100/19703: CD loss is 0.024620261043310165.
# Epoch 0/30 with iteration 10200/19703: CD loss is 0.023951347917318344.
# Epoch 0/30 with iteration 10300/19703: CD loss is 0.022881675511598587.
# Epoch 0/30 with iteration 10400/19703: CD loss is 0.023488998413085938.
# Epoch 0/30 with iteration 10500/19703: CD loss is 0.0236342865973711.
# Epoch 0/30 with iteration 10600/19703: CD loss is 0.02339964732527733.
# Epoch 0/30 with iteration 10700/19703: CD loss is 0.022862423211336136.
# Epoch 0/30 with iteration 10800/19703: CD loss is 0.02355363965034485.
# Epoch 0/30 with iteration 10900/19703: CD loss is 0.025971397757530212.
# Epoch 0/30 with iteration 11000/19703: CD loss is 0.025907598435878754.
# Epoch 0/30 with iteration 11100/19703: CD loss is 0.02603435516357422.
# Epoch 0/30 with iteration 11200/19703: CD loss is 0.024845261126756668.
# Epoch 0/30 with iteration 11300/19703: CD loss is 0.0248987078666687.
# Epoch 0/30 with iteration 11400/19703: CD loss is 0.02151486650109291.
# Epoch 0/30 with iteration 11500/19703: CD loss is 0.02259444072842598.
# Epoch 0/30 with iteration 11600/19703: CD loss is 0.023151593282818794.
# Epoch 0/30 with iteration 11700/19703: CD loss is 0.02357196807861328.
# Epoch 0/30 with iteration 11800/19703: CD loss is 0.023749029263854027.
# Epoch 0/30 with iteration 11900/19703: CD loss is 0.024675702676177025.
# Epoch 0/30 with iteration 12000/19703: CD loss is 0.022380182519555092.
# Epoch 0/30 with iteration 12100/19703: CD loss is 0.023354286327958107.
# Epoch 0/30 with iteration 12200/19703: CD loss is 0.024041013792157173.
# Epoch 0/30 with iteration 12300/19703: CD loss is 0.024580858647823334.
# Epoch 0/30 with iteration 12400/19703: CD loss is 0.02503928728401661.
# Epoch 0/30 with iteration 12500/19703: CD loss is 0.02151564508676529.
# Epoch 0/30 with iteration 12600/19703: CD loss is 0.023784834891557693.
# Epoch 0/30 with iteration 12700/19703: CD loss is 0.02496839314699173.
# Epoch 0/30 with iteration 12800/19703: CD loss is 0.025362517684698105.
# Epoch 0/30 with iteration 12900/19703: CD loss is 0.026443060487508774.
# Epoch 0/30 with iteration 13000/19703: CD loss is 0.02305014617741108.
# Epoch 0/30 with iteration 13100/19703: CD loss is 0.023002875968813896.
# Epoch 0/30 with iteration 13200/19703: CD loss is 0.021740026772022247.
# Epoch 0/30 with iteration 13300/19703: CD loss is 0.02275853417813778.
# Epoch 0/30 with iteration 13400/19703: CD loss is 0.02396342344582081.
# Epoch 0/30 with iteration 13500/19703: CD loss is 0.025687068700790405.
# Epoch 0/30 with iteration 13600/19703: CD loss is 0.023956656455993652.
# Epoch 0/30 with iteration 13700/19703: CD loss is 0.02272740937769413.
# Epoch 0/30 with iteration 13800/19703: CD loss is 0.02677842602133751.
# Epoch 0/30 with iteration 13900/19703: CD loss is 0.02256223000586033.
# Epoch 0/30 with iteration 14000/19703: CD loss is 0.022788746282458305.
# Epoch 0/30 with iteration 14100/19703: CD loss is 0.021332809701561928.
# Epoch 0/30 with iteration 14200/19703: CD loss is 0.028894999995827675.
# Epoch 0/30 with iteration 14300/19703: CD loss is 0.024135537445545197.
# Epoch 0/30 with iteration 14400/19703: CD loss is 0.021832086145877838.
# Epoch 0/30 with iteration 14500/19703: CD loss is 0.022651206701993942.
# Epoch 0/30 with iteration 14600/19703: CD loss is 0.02602474018931389.
# Epoch 0/30 with iteration 14700/19703: CD loss is 0.0234602689743042.
# Epoch 0/30 with iteration 14800/19703: CD loss is 0.020736468955874443.
# Epoch 0/30 with iteration 14900/19703: CD loss is 0.022855106741189957.
# Epoch 0/30 with iteration 15000/19703: CD loss is 0.024930037558078766.
# Epoch 0/30 with iteration 15100/19703: CD loss is 0.020458761602640152.
# Epoch 0/30 with iteration 15200/19703: CD loss is 0.02153710089623928.
# Epoch 0/30 with iteration 15300/19703: CD loss is 0.025742126628756523.
# Epoch 0/30 with iteration 15400/19703: CD loss is 0.022768503054976463.
# Epoch 0/30 with iteration 15500/19703: CD loss is 0.023490160703659058.
# Epoch 0/30 with iteration 15600/19703: CD loss is 0.025679657235741615.
# Epoch 0/30 with iteration 15700/19703: CD loss is 0.021886970847845078.
# Epoch 0/30 with iteration 15800/19703: CD loss is 0.023219730705022812.
# Epoch 0/30 with iteration 15900/19703: CD loss is 0.021982772275805473.
# Epoch 0/30 with iteration 16000/19703: CD loss is 0.023535508662462234.
# Epoch 0/30 with iteration 16100/19703: CD loss is 0.02478683739900589.
# Epoch 0/30 with iteration 16200/19703: CD loss is 0.021946948021650314.
# Epoch 0/30 with iteration 16300/19703: CD loss is 0.02200963720679283.
# Epoch 0/30 with iteration 16400/19703: CD loss is 0.022479262202978134.
# Epoch 0/30 with iteration 16500/19703: CD loss is 0.021698545664548874.
# Epoch 0/30 with iteration 16600/19703: CD loss is 0.02569659985601902.
# Epoch 0/30 with iteration 16700/19703: CD loss is 0.02448452264070511.
# Epoch 0/30 with iteration 16800/19703: CD loss is 0.02588467299938202.
# Epoch 0/30 with iteration 16900/19703: CD loss is 0.024767760187387466.
# Epoch 0/30 with iteration 17000/19703: CD loss is 0.0217033252120018.
# Epoch 0/30 with iteration 17100/19703: CD loss is 0.021318238228559494.
# Epoch 0/30 with iteration 17200/19703: CD loss is 0.02041659876704216.
# Epoch 0/30 with iteration 17300/19703: CD loss is 0.021631205454468727.
# Epoch 0/30 with iteration 17400/19703: CD loss is 0.02193228155374527.
# Epoch 0/30 with iteration 17500/19703: CD loss is 0.022676780819892883.
# Epoch 0/30 with iteration 17600/19703: CD loss is 0.023018676787614822.
# Epoch 0/30 with iteration 17700/19703: CD loss is 0.02402004599571228.
# Epoch 0/30 with iteration 17800/19703: CD loss is 0.02686361037194729.
# Epoch 0/30 with iteration 17900/19703: CD loss is 0.022727515548467636.
# Epoch 0/30 with iteration 18000/19703: CD loss is 0.021077778190374374.
# Epoch 0/30 with iteration 18100/19703: CD loss is 0.02809283882379532.
# Epoch 0/30 with iteration 18200/19703: CD loss is 0.024787548929452896.
# Epoch 0/30 with iteration 18300/19703: CD loss is 0.02119520679116249.
# Epoch 0/30 with iteration 18400/19703: CD loss is 0.025531260296702385.
# Epoch 0/30 with iteration 18500/19703: CD loss is 0.023691054433584213.
# Epoch 0/30 with iteration 18600/19703: CD loss is 0.020773783326148987.
# Epoch 0/30 with iteration 18700/19703: CD loss is 0.022942403331398964.
# Epoch 0/30 with iteration 18800/19703: CD loss is 0.023876510560512543.
# Epoch 0/30 with iteration 18900/19703: CD loss is 0.022212380543351173.
# Epoch 0/30 with iteration 19000/19703: CD loss is 0.01999795064330101.
# Epoch 0/30 with iteration 19100/19703: CD loss is 0.028121381998062134.
# Epoch 0/30 with iteration 19200/19703: CD loss is 0.02118675410747528.
# Epoch 0/30 with iteration 19300/19703: CD loss is 0.023076599463820457.
# Epoch 0/30 with iteration 19400/19703: CD loss is 0.02174457348883152.
# Epoch 0/30 with iteration 19500/19703: CD loss is 0.024119682610034943.
# Epoch 0/30 with iteration 19600/19703: CD loss is 0.022705040872097015.
# Epoch 0/30 with iteration 19700/19703: CD loss is 0.020315593108534813.
# [000/19703] train loss: 504.61453483067453
# Epoch 1/30 with iteration 100/19703: CD loss is 0.020533472299575806.
# Epoch 1/30 with iteration 200/19703: CD loss is 0.02165873907506466.
# Epoch 1/30 with iteration 300/19703: CD loss is 0.026697799563407898.
# Epoch 1/30 with iteration 400/19703: CD loss is 0.0234664473682642.
# Epoch 1/30 with iteration 500/19703: CD loss is 0.019702401012182236.
# Epoch 1/30 with iteration 600/19703: CD loss is 0.022437043488025665.
# Epoch 1/30 with iteration 700/19703: CD loss is 0.023096028715372086.
# Epoch 1/30 with iteration 800/19703: CD loss is 0.022395983338356018.
# Epoch 1/30 with iteration 900/19703: CD loss is 0.02204138971865177.
# Epoch 1/30 with iteration 1000/19703: CD loss is 0.024772876873612404.
# Epoch 1/30 with iteration 1100/19703: CD loss is 0.02316742204129696.
# Epoch 1/30 with iteration 1200/19703: CD loss is 0.02441415563225746.
# Epoch 1/30 with iteration 1300/19703: CD loss is 0.022762583568692207.
# Epoch 1/30 with iteration 1400/19703: CD loss is 0.020583126693964005.
# Epoch 1/30 with iteration 1500/19703: CD loss is 0.02116071805357933.
# Epoch 1/30 with iteration 1600/19703: CD loss is 0.024685699492692947.
# Epoch 1/30 with iteration 1700/19703: CD loss is 0.02329043298959732.
# Epoch 1/30 with iteration 1800/19703: CD loss is 0.021885041147470474.
# Epoch 1/30 with iteration 1900/19703: CD loss is 0.021447908133268356.
# Epoch 1/30 with iteration 2000/19703: CD loss is 0.023006170988082886.
# Epoch 1/30 with iteration 2100/19703: CD loss is 0.02402563951909542.
# Epoch 1/30 with iteration 2200/19703: CD loss is 0.023075910285115242.
# Epoch 1/30 with iteration 2300/19703: CD loss is 0.023010391741991043.
# Epoch 1/30 with iteration 2400/19703: CD loss is 0.02399284765124321.
# Epoch 1/30 with iteration 2500/19703: CD loss is 0.024505795910954475.
# Epoch 1/30 with iteration 2600/19703: CD loss is 0.025418534874916077.
# Epoch 1/30 with iteration 2700/19703: CD loss is 0.02474651113152504.
# Epoch 1/30 with iteration 2800/19703: CD loss is 0.02073540911078453.
# Epoch 1/30 with iteration 2900/19703: CD loss is 0.023784253746271133.
# Epoch 1/30 with iteration 3000/19703: CD loss is 0.020992795005440712.
# Epoch 1/30 with iteration 3100/19703: CD loss is 0.020345497876405716.
# Epoch 1/30 with iteration 3200/19703: CD loss is 0.021188583225011826.
# Epoch 1/30 with iteration 3300/19703: CD loss is 0.02305779419839382.
# Epoch 1/30 with iteration 3400/19703: CD loss is 0.021893033757805824.
# Epoch 1/30 with iteration 3500/19703: CD loss is 0.023715559393167496.
# Epoch 1/30 with iteration 3600/19703: CD loss is 0.025466129183769226.
# Epoch 1/30 with iteration 3700/19703: CD loss is 0.024270426481962204.
# Epoch 1/30 with iteration 3800/19703: CD loss is 0.02110069990158081.
# Epoch 1/30 with iteration 3900/19703: CD loss is 0.024506771937012672.
# Epoch 1/30 with iteration 4000/19703: CD loss is 0.022402431815862656.
# Epoch 1/30 with iteration 4100/19703: CD loss is 0.020640209317207336.
# Epoch 1/30 with iteration 4200/19703: CD loss is 0.020760953426361084.
# Epoch 1/30 with iteration 4300/19703: CD loss is 0.024149585515260696.
# Epoch 1/30 with iteration 4400/19703: CD loss is 0.020337291061878204.
# Epoch 1/30 with iteration 4500/19703: CD loss is 0.022823693230748177.
# Epoch 1/30 with iteration 4600/19703: CD loss is 0.020791063085198402.
# Epoch 1/30 with iteration 4700/19703: CD loss is 0.02449733577668667.
# Epoch 1/30 with iteration 4800/19703: CD loss is 0.020137295126914978.
# Epoch 1/30 with iteration 4900/19703: CD loss is 0.020194582641124725.
# Epoch 1/30 with iteration 5000/19703: CD loss is 0.019940312951803207.
# Epoch 1/30 with iteration 5100/19703: CD loss is 0.022987976670265198.
# Epoch 1/30 with iteration 5200/19703: CD loss is 0.022252198308706284.
# Epoch 1/30 with iteration 5300/19703: CD loss is 0.021545028313994408.
# Epoch 1/30 with iteration 5400/19703: CD loss is 0.019708946347236633.
# Epoch 1/30 with iteration 5500/19703: CD loss is 0.023604055866599083.
# Epoch 1/30 with iteration 5600/19703: CD loss is 0.02448340877890587.
# Epoch 1/30 with iteration 5700/19703: CD loss is 0.02011069282889366.
# Epoch 1/30 with iteration 5800/19703: CD loss is 0.019958876073360443.
# Epoch 1/30 with iteration 5900/19703: CD loss is 0.02462643012404442.
# Epoch 1/30 with iteration 6000/19703: CD loss is 0.02482760325074196.
# Epoch 1/30 with iteration 6100/19703: CD loss is 0.021809309720993042.
# Epoch 1/30 with iteration 6200/19703: CD loss is 0.020038187503814697.
# Epoch 1/30 with iteration 6300/19703: CD loss is 0.025742026045918465.
# Epoch 1/30 with iteration 6400/19703: CD loss is 0.022853318601846695.
# Epoch 1/30 with iteration 6500/19703: CD loss is 0.022556239739060402.
# Epoch 1/30 with iteration 6600/19703: CD loss is 0.02092890441417694.
# Epoch 1/30 with iteration 6700/19703: CD loss is 0.02105122059583664.
# Epoch 1/30 with iteration 6800/19703: CD loss is 0.02157987467944622.
# Epoch 1/30 with iteration 6900/19703: CD loss is 0.020821411162614822.
# Epoch 1/30 with iteration 7000/19703: CD loss is 0.02157820388674736.
# Epoch 1/30 with iteration 7100/19703: CD loss is 0.023688428103923798.
# Epoch 1/30 with iteration 7200/19703: CD loss is 0.01992092840373516.
# Epoch 1/30 with iteration 7300/19703: CD loss is 0.02357468754053116.
# Epoch 1/30 with iteration 7400/19703: CD loss is 0.024305813014507294.
# Epoch 1/30 with iteration 7500/19703: CD loss is 0.020620722323656082.
# Epoch 1/30 with iteration 7600/19703: CD loss is 0.022565435618162155.
# Epoch 1/30 with iteration 7700/19703: CD loss is 0.021408747881650925.
# Epoch 1/30 with iteration 7800/19703: CD loss is 0.02506747655570507.
# Epoch 1/30 with iteration 7900/19703: CD loss is 0.022873934358358383.
# Epoch 1/30 with iteration 8000/19703: CD loss is 0.021185046061873436.
# Epoch 1/30 with iteration 8100/19703: CD loss is 0.022021904587745667.
# Epoch 1/30 with iteration 8200/19703: CD loss is 0.02286503091454506.
# Epoch 1/30 with iteration 8300/19703: CD loss is 0.023432038724422455.
# Epoch 1/30 with iteration 8400/19703: CD loss is 0.021003220230340958.
# Epoch 1/30 with iteration 8500/19703: CD loss is 0.022513726726174355.
# Epoch 1/30 with iteration 8600/19703: CD loss is 0.020608406513929367.
# Epoch 1/30 with iteration 8700/19703: CD loss is 0.021880708634853363.
# Epoch 1/30 with iteration 8800/19703: CD loss is 0.022944986820220947.
# Epoch 1/30 with iteration 8900/19703: CD loss is 0.023155061528086662.
# Epoch 1/30 with iteration 9000/19703: CD loss is 0.023572377860546112.
# Epoch 1/30 with iteration 9100/19703: CD loss is 0.024581050500273705.
# Epoch 1/30 with iteration 9200/19703: CD loss is 0.02485951967537403.
# Epoch 1/30 with iteration 9300/19703: CD loss is 0.02452835813164711.
# Epoch 1/30 with iteration 9400/19703: CD loss is 0.0222819484770298.
# Epoch 1/30 with iteration 9500/19703: CD loss is 0.02003529667854309.
# Epoch 1/30 with iteration 9600/19703: CD loss is 0.025513291358947754.
# Epoch 1/30 with iteration 9700/19703: CD loss is 0.020465774461627007.
# Epoch 1/30 with iteration 9800/19703: CD loss is 0.023822147399187088.
# Epoch 1/30 with iteration 9900/19703: CD loss is 0.025958003476262093.
# Epoch 1/30 with iteration 10000/19703: CD loss is 0.02335045486688614.
# Epoch 1/30 with iteration 10100/19703: CD loss is 0.023294299840927124.
# Epoch 1/30 with iteration 10200/19703: CD loss is 0.02633070945739746.
# Epoch 1/30 with iteration 10300/19703: CD loss is 0.023482196033000946.
# Epoch 1/30 with iteration 10400/19703: CD loss is 0.025733057409524918.
# Epoch 1/30 with iteration 10500/19703: CD loss is 0.018337013199925423.
# Epoch 1/30 with iteration 10600/19703: CD loss is 0.023452799767255783.
# Epoch 1/30 with iteration 10700/19703: CD loss is 0.01951252669095993.
# Epoch 1/30 with iteration 10800/19703: CD loss is 0.019602756947278976.
# Epoch 1/30 with iteration 10900/19703: CD loss is 0.024371597915887833.
# Epoch 1/30 with iteration 11000/19703: CD loss is 0.02237396314740181.
# Epoch 1/30 with iteration 11100/19703: CD loss is 0.02087385207414627.
# Epoch 1/30 with iteration 11200/19703: CD loss is 0.022676784545183182.
# Epoch 1/30 with iteration 11300/19703: CD loss is 0.022457536309957504.
# Epoch 1/30 with iteration 11400/19703: CD loss is 0.02074078470468521.
# Epoch 1/30 with iteration 11500/19703: CD loss is 0.02205948904156685.
# Epoch 1/30 with iteration 11600/19703: CD loss is 0.025101229548454285.
# Epoch 1/30 with iteration 11700/19703: CD loss is 0.01949388161301613.
# Epoch 1/30 with iteration 11800/19703: CD loss is 0.02514873631298542.
# Epoch 1/30 with iteration 11900/19703: CD loss is 0.020134054124355316.
# Epoch 1/30 with iteration 12000/19703: CD loss is 0.02035781368613243.
# Epoch 1/30 with iteration 12100/19703: CD loss is 0.017831770703196526.
# Epoch 1/30 with iteration 12200/19703: CD loss is 0.02144252508878708.
# Epoch 1/30 with iteration 12300/19703: CD loss is 0.02096133679151535.
# Epoch 1/30 with iteration 12400/19703: CD loss is 0.023155266419053078.
# Epoch 1/30 with iteration 12500/19703: CD loss is 0.022499337792396545.
# Epoch 1/30 with iteration 12600/19703: CD loss is 0.024042731150984764.
# Epoch 1/30 with iteration 12700/19703: CD loss is 0.020455462858080864.
# Epoch 1/30 with iteration 12800/19703: CD loss is 0.02105453982949257.
# Epoch 1/30 with iteration 12900/19703: CD loss is 0.02411721833050251.
# Epoch 1/30 with iteration 13000/19703: CD loss is 0.02065310999751091.
# Epoch 1/30 with iteration 13100/19703: CD loss is 0.023252995684742928.
# Epoch 1/30 with iteration 13200/19703: CD loss is 0.0231572724878788.
# Epoch 1/30 with iteration 13300/19703: CD loss is 0.023699648678302765.
# Epoch 1/30 with iteration 13400/19703: CD loss is 0.0232534259557724.
# Epoch 1/30 with iteration 13500/19703: CD loss is 0.02413659542798996.
# Epoch 1/30 with iteration 13600/19703: CD loss is 0.020655959844589233.
# Epoch 1/30 with iteration 13700/19703: CD loss is 0.020352352410554886.
# Epoch 1/30 with iteration 13800/19703: CD loss is 0.02203996106982231.
# Epoch 1/30 with iteration 13900/19703: CD loss is 0.01926521398127079.
# Epoch 1/30 with iteration 14000/19703: CD loss is 0.020722702145576477.
# Epoch 1/30 with iteration 14100/19703: CD loss is 0.020157499238848686.
# Epoch 1/30 with iteration 14200/19703: CD loss is 0.020310133695602417.
# Epoch 1/30 with iteration 14300/19703: CD loss is 0.022914832457900047.
# Epoch 1/30 with iteration 14400/19703: CD loss is 0.021639056503772736.
# Epoch 1/30 with iteration 14500/19703: CD loss is 0.021478231996297836.
# Epoch 1/30 with iteration 14600/19703: CD loss is 0.022180121392011642.
# Epoch 1/30 with iteration 14700/19703: CD loss is 0.022698577493429184.
# Epoch 1/30 with iteration 14800/19703: CD loss is 0.02075728215277195.
# Epoch 1/30 with iteration 14900/19703: CD loss is 0.021584048867225647.
# Epoch 1/30 with iteration 15000/19703: CD loss is 0.023510679602622986.
# Epoch 1/30 with iteration 15100/19703: CD loss is 0.020843427628278732.
# Epoch 1/30 with iteration 15200/19703: CD loss is 0.019953882321715355.
# Epoch 1/30 with iteration 15300/19703: CD loss is 0.021245503798127174.
# Epoch 1/30 with iteration 15400/19703: CD loss is 0.022322263568639755.
# Epoch 1/30 with iteration 15500/19703: CD loss is 0.02335217595100403.
# Epoch 1/30 with iteration 15600/19703: CD loss is 0.0213361456990242.
# Epoch 1/30 with iteration 15700/19703: CD loss is 0.018666302785277367.
# Epoch 1/30 with iteration 15800/19703: CD loss is 0.021148771047592163.
# Epoch 1/30 with iteration 15900/19703: CD loss is 0.02145838737487793.
# Epoch 1/30 with iteration 16000/19703: CD loss is 0.01932726614177227.
# Epoch 1/30 with iteration 16100/19703: CD loss is 0.02465398609638214.
# Epoch 1/30 with iteration 16200/19703: CD loss is 0.021813202649354935.
# Epoch 1/30 with iteration 16300/19703: CD loss is 0.019677024334669113.
# Epoch 1/30 with iteration 16400/19703: CD loss is 0.021470975130796432.
# Epoch 1/30 with iteration 16500/19703: CD loss is 0.020941119641065598.
# Epoch 1/30 with iteration 16600/19703: CD loss is 0.023075582459568977.
# Epoch 1/30 with iteration 16700/19703: CD loss is 0.022278372198343277.
# Epoch 1/30 with iteration 16800/19703: CD loss is 0.0192243829369545.
# Epoch 1/30 with iteration 16900/19703: CD loss is 0.02301289513707161.
# Epoch 1/30 with iteration 17000/19703: CD loss is 0.020257560536265373.
# Epoch 1/30 with iteration 17100/19703: CD loss is 0.023984018713235855.
# Epoch 1/30 with iteration 17200/19703: CD loss is 0.023322027176618576.
# Epoch 1/30 with iteration 17300/19703: CD loss is 0.02330954372882843.
# Epoch 1/30 with iteration 17400/19703: CD loss is 0.019698554649949074.
# Epoch 1/30 with iteration 17500/19703: CD loss is 0.022022582590579987.
# Epoch 1/30 with iteration 17600/19703: CD loss is 0.023286212235689163.
# Epoch 1/30 with iteration 17700/19703: CD loss is 0.02323811687529087.
# Epoch 1/30 with iteration 17800/19703: CD loss is 0.019453171640634537.
# Epoch 1/30 with iteration 17900/19703: CD loss is 0.025712929666042328.
# Epoch 1/30 with iteration 18000/19703: CD loss is 0.022181600332260132.
# Epoch 1/30 with iteration 18100/19703: CD loss is 0.020859245210886.
# Epoch 1/30 with iteration 18200/19703: CD loss is 0.022619031369686127.
# Epoch 1/30 with iteration 18300/19703: CD loss is 0.02420395240187645.
# Epoch 1/30 with iteration 18400/19703: CD loss is 0.02244456484913826.
# Epoch 1/30 with iteration 18500/19703: CD loss is 0.01996416226029396.
# Epoch 1/30 with iteration 18600/19703: CD loss is 0.02186707966029644.
# Epoch 1/30 with iteration 18700/19703: CD loss is 0.02218511514365673.
# Epoch 1/30 with iteration 18800/19703: CD loss is 0.023195181041955948.
# Epoch 1/30 with iteration 18900/19703: CD loss is 0.02245967462658882.
# Epoch 1/30 with iteration 19000/19703: CD loss is 0.020189359784126282.
# Epoch 1/30 with iteration 19100/19703: CD loss is 0.023306118324398994.
# Epoch 1/30 with iteration 19200/19703: CD loss is 0.023921363055706024.
# Epoch 1/30 with iteration 19300/19703: CD loss is 0.021569374948740005.
# Epoch 1/30 with iteration 19400/19703: CD loss is 0.023145079612731934.
# Epoch 1/30 with iteration 19500/19703: CD loss is 0.018553491681814194.
# Epoch 1/30 with iteration 19600/19703: CD loss is 0.02179388329386711.
# Epoch 1/30 with iteration 19700/19703: CD loss is 0.023429132997989655.
# [001/19703] train loss: 440.05346931051463
# Epoch 2/30 with iteration 100/19703: CD loss is 0.026149068027734756.
# Epoch 2/30 with iteration 200/19703: CD loss is 0.018203794956207275.
# Epoch 2/30 with iteration 300/19703: CD loss is 0.02469031699001789.
# Epoch 2/30 with iteration 400/19703: CD loss is 0.022768378257751465.
# Epoch 2/30 with iteration 500/19703: CD loss is 0.020884789526462555.
# Epoch 2/30 with iteration 600/19703: CD loss is 0.021822543814778328.
# Epoch 2/30 with iteration 700/19703: CD loss is 0.020006656646728516.
# Epoch 2/30 with iteration 800/19703: CD loss is 0.0201396644115448.
# Epoch 2/30 with iteration 900/19703: CD loss is 0.021856725215911865.
# Epoch 2/30 with iteration 1000/19703: CD loss is 0.020721299573779106.
# Epoch 2/30 with iteration 1100/19703: CD loss is 0.020779814571142197.
# Epoch 2/30 with iteration 1200/19703: CD loss is 0.02521771378815174.
# Epoch 2/30 with iteration 1300/19703: CD loss is 0.023334946483373642.
# Epoch 2/30 with iteration 1400/19703: CD loss is 0.02160395123064518.
# Epoch 2/30 with iteration 1500/19703: CD loss is 0.02234901860356331.
# Epoch 2/30 with iteration 1600/19703: CD loss is 0.018881451338529587.
# Epoch 2/30 with iteration 1700/19703: CD loss is 0.025884971022605896.
# Epoch 2/30 with iteration 1800/19703: CD loss is 0.018528006970882416.
# Epoch 2/30 with iteration 1900/19703: CD loss is 0.020656682550907135.
# Epoch 2/30 with iteration 2000/19703: CD loss is 0.024409327656030655.
# Epoch 2/30 with iteration 2100/19703: CD loss is 0.023192834109067917.
# Epoch 2/30 with iteration 2200/19703: CD loss is 0.020509205758571625.
# Epoch 2/30 with iteration 2300/19703: CD loss is 0.020147642120718956.
# Epoch 2/30 with iteration 2400/19703: CD loss is 0.0173872672021389.
# Epoch 2/30 with iteration 2500/19703: CD loss is 0.02281993255019188.
# Epoch 2/30 with iteration 2600/19703: CD loss is 0.02012178674340248.
# Epoch 2/30 with iteration 2700/19703: CD loss is 0.021238259971141815.
# Epoch 2/30 with iteration 2800/19703: CD loss is 0.020232226699590683.
# Epoch 2/30 with iteration 2900/19703: CD loss is 0.020611410960555077.
# Epoch 2/30 with iteration 3000/19703: CD loss is 0.020257102325558662.
# Epoch 2/30 with iteration 3100/19703: CD loss is 0.024699166417121887.
# Epoch 2/30 with iteration 3200/19703: CD loss is 0.02039927989244461.
# Epoch 2/30 with iteration 3300/19703: CD loss is 0.024415049701929092.
# Epoch 2/30 with iteration 3400/19703: CD loss is 0.019056139513850212.
# Epoch 2/30 with iteration 3500/19703: CD loss is 0.023273687809705734.
# Epoch 2/30 with iteration 3600/19703: CD loss is 0.021100781857967377.
# Epoch 2/30 with iteration 3700/19703: CD loss is 0.019557707011699677.
# Epoch 2/30 with iteration 3800/19703: CD loss is 0.022514279931783676.
# Epoch 2/30 with iteration 3900/19703: CD loss is 0.02039940096437931.
# Epoch 2/30 with iteration 4000/19703: CD loss is 0.021394934505224228.
# Epoch 2/30 with iteration 4100/19703: CD loss is 0.01926908642053604.
# Epoch 2/30 with iteration 4200/19703: CD loss is 0.022328488528728485.
# Epoch 2/30 with iteration 4300/19703: CD loss is 0.022339165210723877.
# Epoch 2/30 with iteration 4400/19703: CD loss is 0.019478507339954376.
# Epoch 2/30 with iteration 4500/19703: CD loss is 0.024652613326907158.
# Epoch 2/30 with iteration 4600/19703: CD loss is 0.0261286161839962.
# Epoch 2/30 with iteration 4700/19703: CD loss is 0.019261986017227173.
# Epoch 2/30 with iteration 4800/19703: CD loss is 0.02088097669184208.
# Epoch 2/30 with iteration 4900/19703: CD loss is 0.01975063607096672.
# Epoch 2/30 with iteration 5000/19703: CD loss is 0.02139200270175934.
# Epoch 2/30 with iteration 5100/19703: CD loss is 0.020361585542559624.
# Epoch 2/30 with iteration 5200/19703: CD loss is 0.018436728045344353.
# Epoch 2/30 with iteration 5300/19703: CD loss is 0.01799638196825981.
# Epoch 2/30 with iteration 5400/19703: CD loss is 0.018989086151123047.
# Epoch 2/30 with iteration 5500/19703: CD loss is 0.02429342269897461.
# Epoch 2/30 with iteration 5600/19703: CD loss is 0.02283291518688202.
# Epoch 2/30 with iteration 5700/19703: CD loss is 0.0184311643242836.
# Epoch 2/30 with iteration 5800/19703: CD loss is 0.018810391426086426.
# Epoch 2/30 with iteration 5900/19703: CD loss is 0.021535687148571014.
# Epoch 2/30 with iteration 6000/19703: CD loss is 0.021728577092289925.
# Epoch 2/30 with iteration 6100/19703: CD loss is 0.0244833342730999.
# Epoch 2/30 with iteration 6200/19703: CD loss is 0.023248955607414246.
# Epoch 2/30 with iteration 6300/19703: CD loss is 0.019023889675736427.
# Epoch 2/30 with iteration 6400/19703: CD loss is 0.020645521581172943.
# Epoch 2/30 with iteration 6500/19703: CD loss is 0.02234073355793953.
# Epoch 2/30 with iteration 6600/19703: CD loss is 0.020546792075037956.
# Epoch 2/30 with iteration 6700/19703: CD loss is 0.019902246072888374.
# Epoch 2/30 with iteration 6800/19703: CD loss is 0.019736185669898987.
# Epoch 2/30 with iteration 6900/19703: CD loss is 0.024117903783917427.
# Epoch 2/30 with iteration 7000/19703: CD loss is 0.020742142572999.
# Epoch 2/30 with iteration 7100/19703: CD loss is 0.019021745771169662.
# Epoch 2/30 with iteration 7200/19703: CD loss is 0.022294919937849045.
# Epoch 2/30 with iteration 7300/19703: CD loss is 0.021339576691389084.
# Epoch 2/30 with iteration 7400/19703: CD loss is 0.021184740588068962.
# Epoch 2/30 with iteration 7500/19703: CD loss is 0.023434314876794815.
# Epoch 2/30 with iteration 7600/19703: CD loss is 0.021633591502904892.
# Epoch 2/30 with iteration 7700/19703: CD loss is 0.02111274003982544.
# Epoch 2/30 with iteration 7800/19703: CD loss is 0.02413589507341385.
# Epoch 2/30 with iteration 7900/19703: CD loss is 0.02111586555838585.
# Epoch 2/30 with iteration 8000/19703: CD loss is 0.024925973266363144.
# Epoch 2/30 with iteration 8100/19703: CD loss is 0.024083226919174194.
# Epoch 2/30 with iteration 8200/19703: CD loss is 0.02198827639222145.
# Epoch 2/30 with iteration 8300/19703: CD loss is 0.01897568814456463.
# Epoch 2/30 with iteration 8400/19703: CD loss is 0.02457079291343689.
# Epoch 2/30 with iteration 8500/19703: CD loss is 0.020956173539161682.
# Epoch 2/30 with iteration 8600/19703: CD loss is 0.023248936980962753.
# Epoch 2/30 with iteration 8700/19703: CD loss is 0.021202150732278824.
# Epoch 2/30 with iteration 8800/19703: CD loss is 0.01852377876639366.
# Epoch 2/30 with iteration 8900/19703: CD loss is 0.022634103894233704.
# Epoch 2/30 with iteration 9000/19703: CD loss is 0.022891497239470482.
# Epoch 2/30 with iteration 9100/19703: CD loss is 0.02339378371834755.
# Epoch 2/30 with iteration 9200/19703: CD loss is 0.024479566141963005.
# Epoch 2/30 with iteration 9300/19703: CD loss is 0.021052859723567963.
# Epoch 2/30 with iteration 9400/19703: CD loss is 0.023712247610092163.
# Epoch 2/30 with iteration 9500/19703: CD loss is 0.021383538842201233.
# Epoch 2/30 with iteration 9600/19703: CD loss is 0.027591990306973457.
# Epoch 2/30 with iteration 9700/19703: CD loss is 0.020230237394571304.
# Epoch 2/30 with iteration 9800/19703: CD loss is 0.02123970538377762.
# Epoch 2/30 with iteration 9900/19703: CD loss is 0.018748443573713303.
# Epoch 2/30 with iteration 10000/19703: CD loss is 0.02240613102912903.
# Epoch 2/30 with iteration 10100/19703: CD loss is 0.020334595814347267.
# Epoch 2/30 with iteration 10200/19703: CD loss is 0.021951014176011086.
# Epoch 2/30 with iteration 10300/19703: CD loss is 0.0183600801974535.
# Epoch 2/30 with iteration 10400/19703: CD loss is 0.021409373730421066.
# Epoch 2/30 with iteration 10500/19703: CD loss is 0.020114116370677948.
# Epoch 2/30 with iteration 10600/19703: CD loss is 0.023852316662669182.
# Epoch 2/30 with iteration 10700/19703: CD loss is 0.02003367990255356.
# Epoch 2/30 with iteration 10800/19703: CD loss is 0.0184662826359272.
# Epoch 2/30 with iteration 10900/19703: CD loss is 0.020573601126670837.
# Epoch 2/30 with iteration 11000/19703: CD loss is 0.022355344146490097.
# Epoch 2/30 with iteration 11100/19703: CD loss is 0.021838199347257614.
# Epoch 2/30 with iteration 11200/19703: CD loss is 0.022776171565055847.
# Epoch 2/30 with iteration 11300/19703: CD loss is 0.020213468000292778.
# Epoch 2/30 with iteration 11400/19703: CD loss is 0.020566603168845177.
# Epoch 2/30 with iteration 11500/19703: CD loss is 0.02556852251291275.
# Epoch 2/30 with iteration 11600/19703: CD loss is 0.02135459892451763.
# Epoch 2/30 with iteration 11700/19703: CD loss is 0.0211829524487257.
# Epoch 2/30 with iteration 11800/19703: CD loss is 0.0218733511865139.
# Epoch 2/30 with iteration 11900/19703: CD loss is 0.01873539388179779.
# Epoch 2/30 with iteration 12000/19703: CD loss is 0.020021414384245872.
# Epoch 2/30 with iteration 12100/19703: CD loss is 0.021546699106693268.
# Epoch 2/30 with iteration 12200/19703: CD loss is 0.024822130799293518.
# Epoch 2/30 with iteration 12300/19703: CD loss is 0.020599765703082085.
# Epoch 2/30 with iteration 12400/19703: CD loss is 0.021032407879829407.
# Epoch 2/30 with iteration 12500/19703: CD loss is 0.021989494562149048.
# Epoch 2/30 with iteration 12600/19703: CD loss is 0.018884029239416122.
# Epoch 2/30 with iteration 12700/19703: CD loss is 0.023339636623859406.
# Epoch 2/30 with iteration 12800/19703: CD loss is 0.021152477711439133.
# Epoch 2/30 with iteration 12900/19703: CD loss is 0.020003803074359894.
# Epoch 2/30 with iteration 13000/19703: CD loss is 0.01992882788181305.
# Epoch 2/30 with iteration 13100/19703: CD loss is 0.023249521851539612.
# Epoch 2/30 with iteration 13200/19703: CD loss is 0.019898859784007072.
# Epoch 2/30 with iteration 13300/19703: CD loss is 0.02341005764901638.
# Epoch 2/30 with iteration 13400/19703: CD loss is 0.02181738056242466.
# Epoch 2/30 with iteration 13500/19703: CD loss is 0.01857459917664528.
# Epoch 2/30 with iteration 13600/19703: CD loss is 0.01961345225572586.
# Epoch 2/30 with iteration 13700/19703: CD loss is 0.02010328695178032.
# Epoch 2/30 with iteration 13800/19703: CD loss is 0.02624407783150673.
# Epoch 2/30 with iteration 13900/19703: CD loss is 0.023376192897558212.
# Epoch 2/30 with iteration 14000/19703: CD loss is 0.019618142396211624.
# Epoch 2/30 with iteration 14100/19703: CD loss is 0.021806973963975906.
# Epoch 2/30 with iteration 14200/19703: CD loss is 0.019564233720302582.
# Epoch 2/30 with iteration 14300/19703: CD loss is 0.021598298102617264.
# Epoch 2/30 with iteration 14400/19703: CD loss is 0.021307533606886864.
# Epoch 2/30 with iteration 14500/19703: CD loss is 0.02153349667787552.
# Epoch 2/30 with iteration 14600/19703: CD loss is 0.021611493080854416.
# Epoch 2/30 with iteration 14700/19703: CD loss is 0.019540026783943176.
# Epoch 2/30 with iteration 14800/19703: CD loss is 0.01974060758948326.
# Epoch 2/30 with iteration 14900/19703: CD loss is 0.02053685113787651.
# Epoch 2/30 with iteration 15000/19703: CD loss is 0.019550178200006485.
# Epoch 2/30 with iteration 15100/19703: CD loss is 0.023258555680513382.
# Epoch 2/30 with iteration 15200/19703: CD loss is 0.023577924817800522.
# Epoch 2/30 with iteration 15300/19703: CD loss is 0.02008284628391266.
# Epoch 2/30 with iteration 15400/19703: CD loss is 0.02368413843214512.
# Epoch 2/30 with iteration 15500/19703: CD loss is 0.018098480999469757.
# Epoch 2/30 with iteration 15600/19703: CD loss is 0.025239773094654083.
# Epoch 2/30 with iteration 15700/19703: CD loss is 0.022133296355605125.
# Epoch 2/30 with iteration 15800/19703: CD loss is 0.02235933020710945.
# Epoch 2/30 with iteration 15900/19703: CD loss is 0.01922791823744774.
# Epoch 2/30 with iteration 16000/19703: CD loss is 0.0223332978785038.
# Epoch 2/30 with iteration 16100/19703: CD loss is 0.0195036381483078.
# Epoch 2/30 with iteration 16200/19703: CD loss is 0.020459072664380074.
# Epoch 2/30 with iteration 16300/19703: CD loss is 0.023909548297524452.
# Epoch 2/30 with iteration 16400/19703: CD loss is 0.021680474281311035.
# Epoch 2/30 with iteration 16500/19703: CD loss is 0.02129194512963295.
# Epoch 2/30 with iteration 16600/19703: CD loss is 0.01851772330701351.
# Epoch 2/30 with iteration 16700/19703: CD loss is 0.02006671577692032.
# Epoch 2/30 with iteration 16800/19703: CD loss is 0.02091692015528679.
# Epoch 2/30 with iteration 16900/19703: CD loss is 0.02065645530819893.
# Epoch 2/30 with iteration 17000/19703: CD loss is 0.02253398671746254.
# Epoch 2/30 with iteration 17100/19703: CD loss is 0.020481405779719353.
# Epoch 2/30 with iteration 17200/19703: CD loss is 0.021988194435834885.
# Epoch 2/30 with iteration 17300/19703: CD loss is 0.02048984169960022.
# Epoch 2/30 with iteration 17400/19703: CD loss is 0.023247994482517242.
# Epoch 2/30 with iteration 17500/19703: CD loss is 0.020537039265036583.
# Epoch 2/30 with iteration 17600/19703: CD loss is 0.020569756627082825.
# Epoch 2/30 with iteration 17700/19703: CD loss is 0.019352629780769348.
# Epoch 2/30 with iteration 17800/19703: CD loss is 0.021801194176077843.
# Epoch 2/30 with iteration 17900/19703: CD loss is 0.023105673491954803.
# Epoch 2/30 with iteration 18000/19703: CD loss is 0.0236528180539608.
# Epoch 2/30 with iteration 18100/19703: CD loss is 0.022971244528889656.
# Epoch 2/30 with iteration 18200/19703: CD loss is 0.02489304356276989.
# Epoch 2/30 with iteration 18300/19703: CD loss is 0.01927073672413826.
# Epoch 2/30 with iteration 18400/19703: CD loss is 0.02478095144033432.
# Epoch 2/30 with iteration 18500/19703: CD loss is 0.02437536045908928.
# Epoch 2/30 with iteration 18600/19703: CD loss is 0.022246502339839935.
# Epoch 2/30 with iteration 18700/19703: CD loss is 0.022053826600313187.
# Epoch 2/30 with iteration 18800/19703: CD loss is 0.021489981561899185.
# Epoch 2/30 with iteration 18900/19703: CD loss is 0.020050616934895515.
# Epoch 2/30 with iteration 19000/19703: CD loss is 0.02285407856106758.
# Epoch 2/30 with iteration 19100/19703: CD loss is 0.01928088814020157.
# Epoch 2/30 with iteration 19200/19703: CD loss is 0.02298148348927498.
# Epoch 2/30 with iteration 19300/19703: CD loss is 0.01938178762793541.
# Epoch 2/30 with iteration 19400/19703: CD loss is 0.021268274635076523.
# Epoch 2/30 with iteration 19500/19703: CD loss is 0.02022794634103775.
# Epoch 2/30 with iteration 19600/19703: CD loss is 0.01890648901462555.
# Epoch 2/30 with iteration 19700/19703: CD loss is 0.021757518872618675.
# [002/19703] train loss: 420.9546671109274
# Epoch 3/30 with iteration 100/19703: CD loss is 0.018663763999938965.
# Epoch 3/30 with iteration 200/19703: CD loss is 0.017978601157665253.
# Epoch 3/30 with iteration 300/19703: CD loss is 0.02100813388824463.
# Epoch 3/30 with iteration 400/19703: CD loss is 0.01954626850783825.
# Epoch 3/30 with iteration 500/19703: CD loss is 0.02063409984111786.
# Epoch 3/30 with iteration 600/19703: CD loss is 0.018277879804372787.
# Epoch 3/30 with iteration 700/19703: CD loss is 0.019256073981523514.
# Epoch 3/30 with iteration 800/19703: CD loss is 0.02341652475297451.
# Epoch 3/30 with iteration 900/19703: CD loss is 0.020340561866760254.
# Epoch 3/30 with iteration 1000/19703: CD loss is 0.021018512547016144.
# Epoch 3/30 with iteration 1100/19703: CD loss is 0.018281325697898865.
# Epoch 3/30 with iteration 1200/19703: CD loss is 0.018147964030504227.
# Epoch 3/30 with iteration 1300/19703: CD loss is 0.02161218598484993.
# Epoch 3/30 with iteration 1400/19703: CD loss is 0.018224336206912994.
# Epoch 3/30 with iteration 1500/19703: CD loss is 0.021186549216508865.
# Epoch 3/30 with iteration 1600/19703: CD loss is 0.020888011902570724.
# Epoch 3/30 with iteration 1700/19703: CD loss is 0.018324851989746094.
# Epoch 3/30 with iteration 1800/19703: CD loss is 0.020841199904680252.
# Epoch 3/30 with iteration 1900/19703: CD loss is 0.017616773024201393.
# Epoch 3/30 with iteration 2000/19703: CD loss is 0.02328667603433132.
# Epoch 3/30 with iteration 2100/19703: CD loss is 0.01983289048075676.
# Epoch 3/30 with iteration 2200/19703: CD loss is 0.01964736357331276.
# Epoch 3/30 with iteration 2300/19703: CD loss is 0.02117537334561348.
# Epoch 3/30 with iteration 2400/19703: CD loss is 0.02129219099879265.
# Epoch 3/30 with iteration 2500/19703: CD loss is 0.020787369459867477.
# Epoch 3/30 with iteration 2600/19703: CD loss is 0.021024569869041443.
# Epoch 3/30 with iteration 2700/19703: CD loss is 0.019712015986442566.
# Epoch 3/30 with iteration 2800/19703: CD loss is 0.01896282471716404.
# Epoch 3/30 with iteration 2900/19703: CD loss is 0.01955030858516693.
# Epoch 3/30 with iteration 3000/19703: CD loss is 0.021827155724167824.
# Epoch 3/30 with iteration 3100/19703: CD loss is 0.021417800337076187.
# Epoch 3/30 with iteration 3200/19703: CD loss is 0.024552859365940094.
# Epoch 3/30 with iteration 3300/19703: CD loss is 0.021689601242542267.
# Epoch 3/30 with iteration 3400/19703: CD loss is 0.02111690863966942.
# Epoch 3/30 with iteration 3500/19703: CD loss is 0.023894507437944412.
# Epoch 3/30 with iteration 3600/19703: CD loss is 0.019881702959537506.
# Epoch 3/30 with iteration 3700/19703: CD loss is 0.02145344391465187.
# Epoch 3/30 with iteration 3800/19703: CD loss is 0.025663001462817192.
# Epoch 3/30 with iteration 3900/19703: CD loss is 0.024273883551359177.
# Epoch 3/30 with iteration 4000/19703: CD loss is 0.019581884145736694.
# Epoch 3/30 with iteration 4100/19703: CD loss is 0.024582937359809875.
# Epoch 3/30 with iteration 4200/19703: CD loss is 0.019305646419525146.
# Epoch 3/30 with iteration 4300/19703: CD loss is 0.020177239552140236.
# Epoch 3/30 with iteration 4400/19703: CD loss is 0.022901128977537155.
# Epoch 3/30 with iteration 4500/19703: CD loss is 0.018494438380002975.
# Epoch 3/30 with iteration 4600/19703: CD loss is 0.020605605095624924.
# Epoch 3/30 with iteration 4700/19703: CD loss is 0.02097252383828163.
# Epoch 3/30 with iteration 4800/19703: CD loss is 0.02090369537472725.
# Epoch 3/30 with iteration 4900/19703: CD loss is 0.022999271750450134.
# Epoch 3/30 with iteration 5000/19703: CD loss is 0.023277688771486282.
# Epoch 3/30 with iteration 5100/19703: CD loss is 0.0204373337328434.
# Epoch 3/30 with iteration 5200/19703: CD loss is 0.017557451501488686.
# Epoch 3/30 with iteration 5300/19703: CD loss is 0.021780677139759064.
# Epoch 3/30 with iteration 5400/19703: CD loss is 0.022756174206733704.
# Epoch 3/30 with iteration 5500/19703: CD loss is 0.019166208803653717.
# Epoch 3/30 with iteration 5600/19703: CD loss is 0.019965022802352905.
# Epoch 3/30 with iteration 5700/19703: CD loss is 0.02012501284480095.
# Epoch 3/30 with iteration 5800/19703: CD loss is 0.020789042115211487.
# Epoch 3/30 with iteration 5900/19703: CD loss is 0.017642252147197723.
# Epoch 3/30 with iteration 6000/19703: CD loss is 0.023809127509593964.
# Epoch 3/30 with iteration 6100/19703: CD loss is 0.01889372244477272.
# Epoch 3/30 with iteration 6200/19703: CD loss is 0.01861105114221573.
# Epoch 3/30 with iteration 6300/19703: CD loss is 0.022553933784365654.
# Epoch 3/30 with iteration 6400/19703: CD loss is 0.020395662635564804.
# Epoch 3/30 with iteration 6500/19703: CD loss is 0.019626982510089874.
# Epoch 3/30 with iteration 6600/19703: CD loss is 0.018099170178174973.
# Epoch 3/30 with iteration 6700/19703: CD loss is 0.018059581518173218.
# Epoch 3/30 with iteration 6800/19703: CD loss is 0.026939041912555695.
# Epoch 3/30 with iteration 6900/19703: CD loss is 0.018387945368885994.
# Epoch 3/30 with iteration 7000/19703: CD loss is 0.019738396629691124.
# Epoch 3/30 with iteration 7100/19703: CD loss is 0.02369379997253418.
# Epoch 3/30 with iteration 7200/19703: CD loss is 0.02434643544256687.
# Epoch 3/30 with iteration 7300/19703: CD loss is 0.01853586919605732.
# Epoch 3/30 with iteration 7400/19703: CD loss is 0.020519675686955452.
# Epoch 3/30 with iteration 7500/19703: CD loss is 0.019647978246212006.
# Epoch 3/30 with iteration 7600/19703: CD loss is 0.020496506243944168.
# Epoch 3/30 with iteration 7700/19703: CD loss is 0.020301442593336105.
# Epoch 3/30 with iteration 7800/19703: CD loss is 0.018756980076432228.
# Epoch 3/30 with iteration 7900/19703: CD loss is 0.019821178168058395.
# Epoch 3/30 with iteration 8000/19703: CD loss is 0.02068857103586197.
# Epoch 3/30 with iteration 8100/19703: CD loss is 0.01956157758831978.
# Epoch 3/30 with iteration 8200/19703: CD loss is 0.02128830924630165.
# ...
# Epoch 3/30 with iteration 8700/19703: CD loss is 0.020429488271474838.
# Epoch 3/30 with iteration 8800/19703: CD loss is 0.01755169779062271.
# Epoch 3/30 with iteration 8900/19703: CD loss is 0.019665665924549103.
# Epoch 3/30 with iteration 9000/19703: CD loss is 0.020697439089417458.
# Epoch 3/30 with iteration 9100/19703: CD loss is 0.019048720598220825.
# Epoch 3/30 with iteration 9200/19703: CD loss is 0.018313594162464142.
# Epoch 3/30 with iteration 9300/19703: CD loss is 0.020442988723516464.
# Epoch 3/30 with iteration 9400/19703: CD loss is 0.02004060335457325.
# Epoch 3/30 with iteration 9500/19703: CD loss is 0.021646620705723763.
# Epoch 3/30 with iteration 9600/19703: CD loss is 0.02113560028374195.
# Epoch 3/30 with iteration 9700/19703: CD loss is 0.01878461427986622.
# Epoch 3/30 with iteration 9800/19703: CD loss is 0.02209918014705181.
# Epoch 3/30 with iteration 9900/19703: CD loss is 0.01902959682047367.
# Epoch 3/30 with iteration 10000/19703: CD loss is 0.019380245357751846.
# Epoch 3/30 with iteration 10100/19703: CD loss is 0.019851550459861755.
# Epoch 3/30 with iteration 10200/19703: CD loss is 0.021833747625350952.
# Epoch 3/30 with iteration 10300/19703: CD loss is 0.019657740369439125.
# Epoch 3/30 with iteration 10400/19703: CD loss is 0.020597895607352257.
# Epoch 3/30 with iteration 10500/19703: CD loss is 0.02141069620847702.
# Epoch 3/30 with iteration 10600/19703: CD loss is 0.019942792132496834.
# Epoch 3/30 with iteration 10700/19703: CD loss is 0.020488634705543518.
# Epoch 3/30 with iteration 10800/19703: CD loss is 0.021012071520090103.
# Epoch 3/30 with iteration 10900/19703: CD loss is 0.020933005958795547.
# Epoch 3/30 with iteration 11000/19703: CD loss is 0.024685123935341835.
# Epoch 3/30 with iteration 11100/19703: CD loss is 0.018957095220685005.
# Epoch 3/30 with iteration 11200/19703: CD loss is 0.01924244314432144.
# Epoch 3/30 with iteration 11300/19703: CD loss is 0.020962901413440704.
# Epoch 3/30 with iteration 11400/19703: CD loss is 0.023521695286035538.
# Epoch 3/30 with iteration 11500/19703: CD loss is 0.023963330313563347.
# Epoch 3/30 with iteration 11600/19703: CD loss is 0.023209206759929657.
# Epoch 3/30 with iteration 11700/19703: CD loss is 0.019828423857688904.
# Epoch 3/30 with iteration 11800/19703: CD loss is 0.018977899104356766.
# Epoch 3/30 with iteration 11900/19703: CD loss is 0.02197469398379326.
# Epoch 3/30 with iteration 12000/19703: CD loss is 0.019545815885066986.
# Epoch 3/30 with iteration 12100/19703: CD loss is 0.018515678122639656.
# Epoch 3/30 with iteration 12200/19703: CD loss is 0.01884320005774498.
# Epoch 3/30 with iteration 12300/19703: CD loss is 0.021288592368364334.
# Epoch 3/30 with iteration 12400/19703: CD loss is 0.02052552066743374.
# Epoch 3/30 with iteration 12500/19703: CD loss is 0.01853206753730774.
# Epoch 3/30 with iteration 12600/19703: CD loss is 0.021323442459106445.
# Epoch 3/30 with iteration 12700/19703: CD loss is 0.021370261907577515.
# Epoch 3/30 with iteration 12800/19703: CD loss is 0.020171664655208588.
# Epoch 3/30 with iteration 12900/19703: CD loss is 0.018683522939682007.
# Epoch 3/30 with iteration 13000/19703: CD loss is 0.021028678864240646.
# Epoch 3/30 with iteration 13100/19703: CD loss is 0.01998893730342388.
# Epoch 3/30 with iteration 13200/19703: CD loss is 0.01829792931675911.
# Epoch 3/30 with iteration 13300/19703: CD loss is 0.01959577016532421.
# Epoch 3/30 with iteration 13400/19703: CD loss is 0.022946473211050034.
# Epoch 3/30 with iteration 13500/19703: CD loss is 0.019886771216988564.
# Epoch 3/30 with iteration 13600/19703: CD loss is 0.01889021322131157.
# Epoch 3/30 with iteration 13700/19703: CD loss is 0.021695099771022797.
# Epoch 3/30 with iteration 13800/19703: CD loss is 0.018946178257465363.
# Epoch 3/30 with iteration 13900/19703: CD loss is 0.023675324395298958.
# Epoch 3/30 with iteration 14000/19703: CD loss is 0.019294030964374542.
# Epoch 3/30 with iteration 14100/19703: CD loss is 0.020076535642147064.
# Epoch 3/30 with iteration 14200/19703: CD loss is 0.0220829825848341.
# Epoch 3/30 with iteration 14300/19703: CD loss is 0.024295326322317123.
# Epoch 3/30 with iteration 14400/19703: CD loss is 0.020076904445886612.
# Epoch 3/30 with iteration 14500/19703: CD loss is 0.01932716742157936.
# Epoch 3/30 with iteration 14600/19703: CD loss is 0.018790464848279953.
# Epoch 3/30 with iteration 14700/19703: CD loss is 0.02012423612177372.
# Epoch 3/30 with iteration 14800/19703: CD loss is 0.01919759437441826.
# Epoch 3/30 with iteration 14900/19703: CD loss is 0.019748101010918617.
# Epoch 3/30 with iteration 15000/19703: CD loss is 0.02090117707848549.
# Epoch 3/30 with iteration 15100/19703: CD loss is 0.023808062076568604.
# Epoch 3/30 with iteration 15200/19703: CD loss is 0.020894894376397133.
# Epoch 3/30 with iteration 15300/19703: CD loss is 0.022116858512163162.
# Epoch 3/30 with iteration 15400/19703: CD loss is 0.022063691169023514.
# Epoch 3/30 with iteration 15500/19703: CD loss is 0.027097951620817184.
# Epoch 3/30 with iteration 15600/19703: CD loss is 0.02060941979289055.
# Epoch 3/30 with iteration 15700/19703: CD loss is 0.021088412031531334.
# Epoch 3/30 with iteration 15800/19703: CD loss is 0.021627385169267654.
# Epoch 3/30 with iteration 15900/19703: CD loss is 0.02065775915980339.
# Epoch 3/30 with iteration 16000/19703: CD loss is 0.020076537504792213.
# Epoch 3/30 with iteration 16100/19703: CD loss is 0.02010410651564598.
# Epoch 3/30 with iteration 16200/19703: CD loss is 0.017985716462135315.
# Epoch 3/30 with iteration 16300/19703: CD loss is 0.018951019272208214.
# Epoch 3/30 with iteration 16400/19703: CD loss is 0.019499104470014572.
# Epoch 3/30 with iteration 16500/19703: CD loss is 0.020759910345077515.
# Epoch 3/30 with iteration 16600/19703: CD loss is 0.01988174021244049.
# Epoch 3/30 with iteration 16700/19703: CD loss is 0.018444906920194626.
# Epoch 3/30 with iteration 16800/19703: CD loss is 0.022850874811410904.
# Epoch 3/30 with iteration 16900/19703: CD loss is 0.019381143152713776.
# Epoch 3/30 with iteration 17000/19703: CD loss is 0.023825854063034058.
# Epoch 3/30 with iteration 17100/19703: CD loss is 0.021593410521745682.
# Epoch 3/30 with iteration 17200/19703: CD loss is 0.021901745349168777.
# Epoch 3/30 with iteration 17300/19703: CD loss is 0.0213148295879364.
# Epoch 3/30 with iteration 17400/19703: CD loss is 0.022278500720858574.
# Epoch 3/30 with iteration 17500/19703: CD loss is 0.0191547479480505.
# Epoch 3/30 with iteration 17600/19703: CD loss is 0.02000255137681961.
# Epoch 3/30 with iteration 17700/19703: CD loss is 0.021354034543037415.
# Epoch 3/30 with iteration 17800/19703: CD loss is 0.018239378929138184.
# Epoch 3/30 with iteration 17900/19703: CD loss is 0.023894554004073143.
# Epoch 3/30 with iteration 18000/19703: CD loss is 0.01887398585677147.
# Epoch 3/30 with iteration 18100/19703: CD loss is 0.022128459066152573.
# Epoch 3/30 with iteration 18200/19703: CD loss is 0.02036472037434578.
# Epoch 3/30 with iteration 18300/19703: CD loss is 0.018534619361162186.
# Epoch 3/30 with iteration 18400/19703: CD loss is 0.01963263377547264.
# Epoch 3/30 with iteration 18500/19703: CD loss is 0.020882632583379745.
# Epoch 3/30 with iteration 18600/19703: CD loss is 0.01996646448969841.
# Epoch 3/30 with iteration 18700/19703: CD loss is 0.023387253284454346.
# Epoch 3/30 with iteration 18800/19703: CD loss is 0.020477155223488808.
# Epoch 3/30 with iteration 18900/19703: CD loss is 0.01931912824511528.
# Epoch 3/30 with iteration 19000/19703: CD loss is 0.01734646037220955.
# Epoch 3/30 with iteration 19100/19703: CD loss is 0.019726447761058807.
# Epoch 3/30 with iteration 19200/19703: CD loss is 0.021758850663900375.
# Epoch 3/30 with iteration 19300/19703: CD loss is 0.021846765652298927.
# Epoch 3/30 with iteration 19400/19703: CD loss is 0.018062734976410866.
# Epoch 3/30 with iteration 19500/19703: CD loss is 0.0215289406478405.
# Epoch 3/30 with iteration 19600/19703: CD loss is 0.021542232483625412.
# Epoch 3/30 with iteration 19700/19703: CD loss is 0.019760938361287117.
# [003/19703] train loss: 407.2787239840254
# Epoch 4/30 with iteration 100/19703: CD loss is 0.020475197583436966.
# Epoch 4/30 with iteration 200/19703: CD loss is 0.021451689302921295.
# Epoch 4/30 with iteration 300/19703: CD loss is 0.018194418400526047.
# Epoch 4/30 with iteration 400/19703: CD loss is 0.022952109575271606.
# Epoch 4/30 with iteration 500/19703: CD loss is 0.01865781843662262.
# Epoch 4/30 with iteration 600/19703: CD loss is 0.01874518394470215.
# Epoch 4/30 with iteration 700/19703: CD loss is 0.02019025757908821.
# Epoch 4/30 with iteration 800/19703: CD loss is 0.019458476454019547.
# Epoch 4/30 with iteration 900/19703: CD loss is 0.022971196100115776.
# Epoch 4/30 with iteration 1000/19703: CD loss is 0.022898536175489426.
# Epoch 4/30 with iteration 1100/19703: CD loss is 0.019684795290231705.
# Epoch 4/30 with iteration 1200/19703: CD loss is 0.020578725263476372.
# Epoch 4/30 with iteration 1300/19703: CD loss is 0.016608210280537605.
# Epoch 4/30 with iteration 1400/19703: CD loss is 0.02166333608329296.
# Epoch 4/30 with iteration 1500/19703: CD loss is 0.022565819323062897.
# Epoch 4/30 with iteration 1600/19703: CD loss is 0.01814606599509716.
# Epoch 4/30 with iteration 1700/19703: CD loss is 0.018326139077544212.
# Epoch 4/30 with iteration 1800/19703: CD loss is 0.01846735179424286.
# Epoch 4/30 with iteration 1900/19703: CD loss is 0.018170401453971863.
# Epoch 4/30 with iteration 2000/19703: CD loss is 0.024951130151748657.
# Epoch 4/30 with iteration 2100/19703: CD loss is 0.020413503050804138.
# Epoch 4/30 with iteration 2200/19703: CD loss is 0.019741766154766083.
# Epoch 4/30 with iteration 2300/19703: CD loss is 0.022677648812532425.
# Epoch 4/30 with iteration 2400/19703: CD loss is 0.020005377009510994.
# Epoch 4/30 with iteration 2500/19703: CD loss is 0.020385637879371643.
# Epoch 4/30 with iteration 2600/19703: CD loss is 0.019916901364922523.
# Epoch 4/30 with iteration 2700/19703: CD loss is 0.020404258742928505.
# Epoch 4/30 with iteration 2800/19703: CD loss is 0.02081628143787384.
# Epoch 4/30 with iteration 2900/19703: CD loss is 0.020174827426671982.
# Epoch 4/30 with iteration 3000/19703: CD loss is 0.022594889625906944.
# Epoch 4/30 with iteration 3100/19703: CD loss is 0.02152305655181408.
# Epoch 4/30 with iteration 3200/19703: CD loss is 0.01783544383943081.
# Epoch 4/30 with iteration 3300/19703: CD loss is 0.017866022884845734.
# Epoch 4/30 with iteration 3400/19703: CD loss is 0.0221939068287611.
# Epoch 4/30 with iteration 3500/19703: CD loss is 0.022770725190639496.
# Epoch 4/30 with iteration 3600/19703: CD loss is 0.01967005245387554.
# Epoch 4/30 with iteration 3700/19703: CD loss is 0.01717360131442547.
# Epoch 4/30 with iteration 3800/19703: CD loss is 0.016749048605561256.
# Epoch 4/30 with iteration 3900/19703: CD loss is 0.019108958542346954.
# Epoch 4/30 with iteration 4000/19703: CD loss is 0.016944415867328644.
# Epoch 4/30 with iteration 4100/19703: CD loss is 0.01973142847418785.
# Epoch 4/30 with iteration 4200/19703: CD loss is 0.01881258934736252.
# Epoch 4/30 with iteration 4300/19703: CD loss is 0.019566085189580917.
# Epoch 4/30 with iteration 4400/19703: CD loss is 0.020833734422922134.
# Epoch 4/30 with iteration 4500/19703: CD loss is 0.019903050735592842.
# Epoch 4/30 with iteration 4600/19703: CD loss is 0.019918043166399002.
# Epoch 4/30 with iteration 4700/19703: CD loss is 0.02133917808532715.
# Epoch 4/30 with iteration 4800/19703: CD loss is 0.01501607708632946.
# Epoch 4/30 with iteration 4900/19703: CD loss is 0.021631116047501564.
# Epoch 4/30 with iteration 5000/19703: CD loss is 0.019649822264909744.
# Epoch 4/30 with iteration 5100/19703: CD loss is 0.019645381718873978.
# Epoch 4/30 with iteration 5200/19703: CD loss is 0.021129092201590538.
# Epoch 4/30 with iteration 5300/19703: CD loss is 0.01786554418504238.
# Epoch 4/30 with iteration 5400/19703: CD loss is 0.019010469317436218.
# Epoch 4/30 with iteration 5500/19703: CD loss is 0.02331947162747383.
# Epoch 4/30 with iteration 5600/19703: CD loss is 0.01840672828257084.
# Epoch 4/30 with iteration 5700/19703: CD loss is 0.02149849198758602.
# Epoch 4/30 with iteration 5800/19703: CD loss is 0.02198568359017372.
# Epoch 4/30 with iteration 5900/19703: CD loss is 0.0172337107360363.
# Epoch 4/30 with iteration 6000/19703: CD loss is 0.020646842196583748.
# Epoch 4/30 with iteration 6100/19703: CD loss is 0.02037205919623375.
# Epoch 4/30 with iteration 6200/19703: CD loss is 0.02399921789765358.
# Epoch 4/30 with iteration 6300/19703: CD loss is 0.018780633807182312.
# Epoch 4/30 with iteration 6400/19703: CD loss is 0.019295604899525642.
# Epoch 4/30 with iteration 6500/19703: CD loss is 0.0208769328892231.
# Epoch 4/30 with iteration 6600/19703: CD loss is 0.01981334760785103.
# Epoch 4/30 with iteration 6700/19703: CD loss is 0.02031901851296425.
# Epoch 4/30 with iteration 6800/19703: CD loss is 0.018281275406479836.
# Epoch 4/30 with iteration 6900/19703: CD loss is 0.02020961046218872.
# Epoch 4/30 with iteration 7000/19703: CD loss is 0.019744452089071274.
# Epoch 4/30 with iteration 7100/19703: CD loss is 0.017448727041482925.
# Epoch 4/30 with iteration 7200/19703: CD loss is 0.018394142389297485.
# Epoch 4/30 with iteration 7300/19703: CD loss is 0.023626049980521202.
# Epoch 4/30 with iteration 7400/19703: CD loss is 0.018410246819257736.
# Epoch 4/30 with iteration 7500/19703: CD loss is 0.019828390330076218.
# Epoch 4/30 with iteration 7600/19703: CD loss is 0.0213173720985651.
# Epoch 4/30 with iteration 7700/19703: CD loss is 0.022128097712993622.
# Epoch 4/30 with iteration 7800/19703: CD loss is 0.019879905506968498.
# Epoch 4/30 with iteration 7900/19703: CD loss is 0.02001165971159935.
# Epoch 4/30 with iteration 8000/19703: CD loss is 0.020949479192495346.
# Epoch 4/30 with iteration 8100/19703: CD loss is 0.02139471285045147.
# Epoch 4/30 with iteration 8200/19703: CD loss is 0.021529819816350937.
# Epoch 4/30 with iteration 8300/19703: CD loss is 0.018216196447610855.
# Epoch 4/30 with iteration 8400/19703: CD loss is 0.021201007068157196.
# Epoch 4/30 with iteration 8500/19703: CD loss is 0.01991744339466095.
# Epoch 4/30 with iteration 8600/19703: CD loss is 0.021715594455599785.
# Epoch 4/30 with iteration 8700/19703: CD loss is 0.019547928124666214.
# Epoch 4/30 with iteration 8800/19703: CD loss is 0.023696966469287872.
# Epoch 4/30 with iteration 8900/19703: CD loss is 0.017632078379392624.
# Epoch 4/30 with iteration 9000/19703: CD loss is 0.019948743283748627.
# Epoch 4/30 with iteration 9100/19703: CD loss is 0.02049734629690647.
# Epoch 4/30 with iteration 9200/19703: CD loss is 0.017620328813791275.
# Epoch 4/30 with iteration 9300/19703: CD loss is 0.018764590844511986.
# Epoch 4/30 with iteration 9400/19703: CD loss is 0.017480473965406418.
# Epoch 4/30 with iteration 9500/19703: CD loss is 0.019020751118659973.
# Epoch 4/30 with iteration 9600/19703: CD loss is 0.018603164702653885.
# Epoch 4/30 with iteration 9700/19703: CD loss is 0.020863326266407967.
# Epoch 4/30 with iteration 9800/19703: CD loss is 0.016620738431811333.
# Epoch 4/30 with iteration 9900/19703: CD loss is 0.020294347777962685.
# Epoch 4/30 with iteration 10000/19703: CD loss is 0.01889176294207573.
# Epoch 4/30 with iteration 10100/19703: CD loss is 0.016610335558652878.
# Epoch 4/30 with iteration 10200/19703: CD loss is 0.022352134808897972.
# Epoch 4/30 with iteration 10300/19703: CD loss is 0.02596326917409897.
# Epoch 4/30 with iteration 10400/19703: CD loss is 0.01801076903939247.
# Epoch 4/30 with iteration 10500/19703: CD loss is 0.020038986578583717.
# Epoch 4/30 with iteration 10600/19703: CD loss is 0.021046660840511322.
# Epoch 4/30 with iteration 10700/19703: CD loss is 0.020729873329401016.
# Epoch 4/30 with iteration 10800/19703: CD loss is 0.02136031538248062.
# Epoch 4/30 with iteration 10900/19703: CD loss is 0.01975947991013527.
# Epoch 4/30 with iteration 11000/19703: CD loss is 0.020636972039937973.
# Epoch 4/30 with iteration 11100/19703: CD loss is 0.02088448777794838.
# Epoch 4/30 with iteration 11200/19703: CD loss is 0.021696552634239197.
# Epoch 4/30 with iteration 11300/19703: CD loss is 0.01731685921549797.

# %% [markdown]
# Normal, L2 loss

# %%
from training import train_2d_to_3d

generalization_config = {
    'experiment_name': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/2d_logs/normal/L2',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'bottleneck': 512,
    "cat":13,
    'batch_size': 32,
    "loss_criterion":"L2",
    "final_layer":"normal",
    "3d_encoder_path":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/additional_epoches/model_epoch_500.pth",
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    'max_epochs': 30,  
    'print_every_n': 5,
    'validate_every_n': 5,
    "autoencoder_bottleneck":512,
    "autoencoder_hidden_size":256,
    "autoencoder_output_size":2048*3,
    "alpha":None,
    "penalty_angle":None,
    "lambda":None


}

train_2d_to_3d.main(generalization_config)

# %% [markdown]
# Variational

# %%
from training import train_2d_to_3d

generalization_config = {
    'experiment_name': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/2d_logs/normal',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'bottleneck': 512,
    "cat":13,
    'batch_size': 32,
    "loss_criterion":"variational",
    "final_layer":"variational",
    "3d_encoder_path":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/additional_epoches/model_epoch_500.pth",
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    'max_epochs': 30,  
    'print_every_n': 5,
    'validate_every_n': 5,
    "autoencoder_bottleneck":512,
    "autoencoder_hidden_size":256,
    "autoencoder_output_size":2048*3,
    "alpha":0.2,
    "penalty_angle":20,
    "lambda":5.5


}

train_2d_to_3d.main(generalization_config)

# %% [markdown]
# ### Infer pointclouds using trained 2D Encoder and 3D Decoder models

# %% [markdown]
# Variational inferences:

# %%
from inference import inference_2d_to_3d 

generalization_config = {
    'experiment_name': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/2d_logs/normal',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'bottleneck': 512,
    "cat":13,
    'batch_size': 32,
    "loss_criterion":"normal",
    "final_layer":"normal",
    "3d_encoder_path":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/additional_epoches/model_epoch_500.pth",
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    'max_epochs': 30,  
    'print_every_n': 5,
    'visualize_every_n': 5,
    "autoencoder_bottleneck":512,
    "autoencoder_hidden_size":256,
    "autoencoder_output_size":2048*3

}

# %% [markdown]
# Normal inferences:

# %% [markdown]
# Using L1 in the training

# %%
from inference.infer_2d_to_3d import Inference2DToPointCloudNormal

id=torch.randint(0,len(test_dataset))
val_config={"final_layer" : "normal",
        "bottleneck" : 512,
        "input_size" : None,
        "hidden_size" : None,
        "output_size" : None,
        "bnorm" : True,
        "bnorm_final" : False,
        "regularizer" : None,
        "weight_decay" : 0.001,
        "dropout_prob" : None}
Inference2DToPointCloudNormal(test_dataset[id],"content/3d-lmnet-pytorch/runs/2d_to_3d_normal", "content/3d-lmnet-pytorch/runs/3d_pointcloud_decoder",val_config,device)

# %% [markdown]
# Using L2 in the training

# %%
from inference.infer_2d_to_3d import Inference2DToPointCloudNormal

id=torch.randint(0,len(test_dataset))
val_config={"final_layer" : "normal",
        "bottleneck" : 512,
        "input_size" : None,
        "hidden_size" : None,
        "output_size" : None,
        "bnorm" : True,
        "bnorm_final" : False,
        "regularizer" : None,
        "weight_decay" : 0.001,
        "dropout_prob" : None}
Inference2DToPointCloudNormal(test_dataset[id],"content/3d-lmnet-pytorch/runs/2d_to_3d_normal", "content/3d-lmnet-pytorch/runs/3d_pointcloud_decoder",val_config,device)

# %% [markdown]
# ## 3D Autoencoder Training

# %%
from training import train_ae


    # parser.add_argument("--root", type=str, default="./data")
    # parser.add_argument("--npoints", type=int, default=2048)
    # parser.add_argument("--mpoints", type=int, default=2025)
    # parser.add_argument("--batch_size", type=int, default=16)
    # parser.add_argument("--lr", type=float, default=1e-4)
    # parser.add_argument("--weight_decay", type=float, default=1e-6)
    # parser.add_argument("--epochs", type=int, default=400)
    # parser.add_argument("--num_workers", type=int, default=4)
    # parser.add_argument("--log_dir", type=str, default="./log")

generalization_config = {
    'root': './3d-lmnet-pytorch/',
    'experiment_name': '3d_autoencoder',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'npoints': 2048,
    'mpoints': 2025,
    'lr': 1e-4,
    "autoencoder":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/additional_epoches/model_epoch_300.pth",
    'weight_decay': 1e-6,
    'bottleneck': 512,
    'batch_size': 32,
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    'max_epochs': 200,  
    'num_workers': 4,
    "input_size" : 256,
    "hidden_size" : 256,
    "output_size" : 2048*3,
    'log_dir': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/additional_epoches',
    'print_every_n': 5,
    'visualize_every_n': 5,
}

train_ae.main(generalization_config)
# Out:
#  initial input 512 initial hidden 16 initial output 3
# Begin Training...
# initial point cloud size torch.Size([16, 3, 2048])
# tensor size after encoder torch.Size([16, 512])
# tensor size after decoder torch.Size([16, 3])
# recons size torch.Size([16, 3, 1])
# point cloud size before loss function torch.Size([16, 2048, 3])
# recons size before loss function torch.Size([16, 1, 3])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-55adbbeb75b6> in <module>
#      35 }
#      36
# ---> 37 train_ae.main(generalization_config)
#
# /content/3d-lmnet-pytorch/3d-lmnet-pytorch/training/train_ae.py in main(config)
#     104             print("recons size before loss function " + str(recons.size()))
#     105
# --> 106             loss = chamfer_loss(point_clouds, recons)
#     107
#     108            # optimizer.zero_grad()
#
# /content/3d-lmnet-pytorch/3d-lmnet-pytorch/utils/losses.py in __call__(self, y_true, y_pred)
#      27
#      28     def __call__(self, y_true, y_pred):
# ---> 29         dists_forward, _ = torch.cdist(y_true, y_pred)
#      30         dists_backward, _ = torch.cdist(y_pred, y_true)
#      31
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ### 3D Inferences

# %%
from inference import infer_3d

generalization_config = {
    "autoencoder":"/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/logs/model_epoch_500.pth",
    'bottleneck': 512,
    'batch_size': 1,
    'num_workers': 4,
    "input_size" : 256,
    "hidden_size" : 256,
    "output_size" : 2048*3,
}

infer_3d.main(generalization_config)
