# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# We assume you uploaded the exercise folder in root Google Drive folder
# !cp -r /content/drive/MyDrive/3d-lmnet-pytorch 3d-lmnet-pytorch
os.chdir('/content/drive/MyDrive/3d-lmnet-pytorch')
print('Installing requirements')
# !pip install -r requirements.txt

# Make sure you restart runtime when directed by Colab
# Out:
# Mounted at /content/drive
# Installing requirements
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jupyter>=1.0.0
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting K3D>=2.9.4
#   Downloading k3d-2.15.2-py3-none-any.whl (23.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.0/23.0 MB 19.4 MB/s eta 0:00:00
# Collecting matplotlib>=3.4.1
#   Downloading matplotlib-3.6.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 109.7 MB/s eta 0:00:00
# Collecting trimesh>=3.9.14
#   Downloading trimesh-3.18.1-py3-none-any.whl (670 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.9/670.9 KB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 5)) (1.13.1+cu116)
# Collecting pytorch-lightning>=1.2.8
#   Downloading pytorch_lightning-1.9.0-py3-none-any.whl (825 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 KB 69.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image>=0.18.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 7)) (0.18.3)
# Collecting pyrender>=0.1.43
#   Downloading pyrender-0.1.45-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.3 MB/s eta 0:00:00
# Collecting moviepy>=1.0.3
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 KB 42.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pillow>=7.2.0
#   Downloading Pillow-9.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 107.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 11)) (4.64.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 12)) (1.7.3)
# Requirement already satisfied: numpy>=1.19.4 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 13)) (1.21.6)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.8/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 1)) (5.3.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.8/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 1)) (7.7.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.8/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 1)) (5.6.1)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.8/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.8/dist-packages (from jupyter>=1.0.0->-r requirements.txt (line 1)) (5.7.16)
# Collecting qtconsole
#   Downloading qtconsole-5.4.0-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.0/121.0 KB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: traitlets in /usr/local/lib/python3.8/dist-packages (from K3D>=2.9.4->-r requirements.txt (line 2)) (5.7.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.8/dist-packages (from K3D>=2.9.4->-r requirements.txt (line 2)) (1.0.4)
# Collecting traittypes
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4.1->-r requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4.1->-r requirements.txt (line 3)) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 65.0 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 34.8 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4.1->-r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4.1->-r requirements.txt (line 3)) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4.1->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.8.1->-r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (6.0)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.0-py3-none-any.whl (512 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.4/512.4 KB 49.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (2022.11.0)
# Collecting lightning-utilities>=0.4.2
#   Downloading lightning_utilities-0.5.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.18.1->-r requirements.txt (line 7)) (1.4.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.18.1->-r requirements.txt (line 7)) (3.0)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.18.1->-r requirements.txt (line 7)) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.18.1->-r requirements.txt (line 7)) (2022.10.10)
# Collecting pyglet>=1.4.10
#   Downloading pyglet-2.0.3-py3-none-any.whl (968 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 968.6/968.6 KB 74.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from pyrender>=0.1.43->-r requirements.txt (line 8)) (1.15.0)
# Collecting PyOpenGL==3.1.0
#   Downloading PyOpenGL-3.1.0.zip (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 84.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting freetype-py
#   Downloading freetype_py-2.3.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (978 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.9/978.9 KB 71.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.8/dist-packages (from moviepy>=1.0.3->-r requirements.txt (line 9)) (4.4.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from moviepy>=1.0.3->-r requirements.txt (line 9)) (2.25.1)
# Collecting proglog<=1.0.0
#   Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Collecting imageio_ffmpeg>=0.2.0
#   Downloading imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 63.0 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (3.8.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (3.0.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (7.9.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.8/dist-packages (from ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.8/dist-packages (from ipykernel->jupyter>=1.0.0->-r requirements.txt (line 1)) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipykernel->jupyter>=1.0.0->-r requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.3->-r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.3->-r requirements.txt (line 9)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.3->-r requirements.txt (line 9)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.3->-r requirements.txt (line 9)) (1.24.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from jupyter-console->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from jupyter-console->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: nbformat>=4.4 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (5.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: jinja2>=2.4 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.11.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.4)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.8/dist-packages (from nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (5.1.3)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.13.3)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.8/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.15.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.8/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 1)) (23.2.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.8/dist-packages (from notebook->jupyter>=1.0.0->-r requirements.txt (line 1)) (1.8.0)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.3.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 KB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (6.0.4)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.2.8->-r requirements.txt (line 6)) (4.0.2)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.8 MB/s eta 0:00:00
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=4.0.0->ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2>=2.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.6.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat>=4.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat>=4.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (4.3.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.8/dist-packages (from terminado>=0.8.1->notebook->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from bleach->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (5.10.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (0.19.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.4->nbconvert->jupyter>=1.0.0->-r requirements.txt (line 1)) (3.11.0)
# Building wheels for collected packages: PyOpenGL, moviepy
#   Building wheel for PyOpenGL (setup.py) ... done
#   Created wheel for PyOpenGL: filename=PyOpenGL-3.1.0-py3-none-any.whl size=1745210 sha256=1d29d19ecdaed7dacb87c08b44df3f29f72eac29bf8cacc5ae6f8729ae7b76e3
#   Stored in directory: /root/.cache/pip/wheels/85/ff/54/41f30bb227befd3dde302de39f9ba042589e8b4f93723107f2
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110742 sha256=692bce6cc9c207b5e3cadf2b09f213622e0f128388c41fd7fc496ed31d102a24
#   Stored in directory: /root/.cache/pip/wheels/e4/a4/db/0368d3a04033da662e13926594b3a8cf1aa4ffeefe570cfac1
# Successfully built PyOpenGL moviepy
# Installing collected packages: PyOpenGL, pyglet, trimesh, traittypes, proglog, pillow, jedi, imageio_ffmpeg, freetype-py, fonttools, contourpy, torchmetrics, qtpy, matplotlib, lightning-utilities, pyrender, moviepy, qtconsole, pytorch-lightning, K3D, jupyter
#   Attempting uninstall: PyOpenGL
#     Found existing installation: PyOpenGL 3.1.6
#     Uninstalling PyOpenGL-3.1.6:
#       Successfully uninstalled PyOpenGL-3.1.6
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: moviepy
#     Found existing installation: moviepy 0.2.3.5
#     Uninstalling moviepy-0.2.3.5:
#       Successfully uninstalled moviepy-0.2.3.5
# Successfully installed K3D-2.15.2 PyOpenGL-3.1.0 contourpy-1.0.7 fonttools-4.38.0 freetype-py-2.3.0 imageio_ffmpeg-0.4.8 jedi-0.18.2 jupyter-1.0.0 lightning-utilities-0.5.0 matplotlib-3.6.3 moviepy-1.0.3 pillow-9.4.0 proglog-0.1.10 pyglet-2.0.3 pyrender-0.1.45 pytorch-lightning-1.9.0 qtconsole-5.4.0 qtpy-2.3.0 torchmetrics-0.11.0 traittypes-0.2.1 trimesh-3.18.1

# %%
import os
import sys
import torch
os.chdir('/content/3d-lmnet-pytorch/3d-lmnet-pytorch')
sys.path.insert(1, "/content/3d-lmnet-pytorch/3d-lmnet-pytorch")
print('CUDA availability:', torch.cuda.is_available())
# Out:
# CUDA availability: True

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import numpy as np
import matplotlib as plt
import k3d
import trimesh
import torch
import skimage

# %%
torch.cuda.is_available()
need_pytorch3d=False
try:
    import pytorch3d
except ModuleNotFoundError:
    need_pytorch3d=True
if need_pytorch3d:
    if sys.platform.startswith("linux"):
        # We try to install PyTorch3D via a released wheel.
        pyt_version_str=torch.__version__.split("+")[0].replace(".", "")
        version_str="".join([
            f"py3{sys.version_info.minor}_cu",
            torch.version.cuda.replace(".",""),
            f"_pyt{pyt_version_str}"
        ])
        # !pip install pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/{version_str}/download.html
    else:
        # We try to install PyTorch3D from source.
        # !curl -LO https://github.com/NVIDIA/cub/archive/1.10.0.tar.gz
        # !tar xzf 1.10.0.tar.gz
        os.environ["CUB_HOME"] = os.getcwd() + "/cub-1.10.0"
        # !pip install 'git+https://github.com/facebookresearch/pytorch3d.git@stable'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/py38_cu116_pyt1131/download.html
# Collecting pytorch3d
#   Downloading https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/py38_cu116_pyt1131/pytorch3d-0.7.2-cp38-cp38-linux_x86_64.whl (72.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.8/72.8 MB 10.6 MB/s eta 0:00:00
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 KB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 KB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from fvcore->pytorch3d) (1.21.6)
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from fvcore->pytorch3d) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from fvcore->pytorch3d) (4.64.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.8/dist-packages (from fvcore->pytorch3d) (2.2.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from fvcore->pytorch3d) (9.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from fvcore->pytorch3d) (0.8.10)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.8/dist-packages (from iopath->pytorch3d) (4.4.0)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61431 sha256=dae88102cb2f454fff61746aa16f92e58e8ccdc1de939b044015ddbd05967f9b
#   Stored in directory: /root/.cache/pip/wheels/b8/79/07/c0e9367f5b5ea325e246bd73651e8af175fabbef943043b1cc
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31547 sha256=944e590e6d0ea021809791109c2f48ea3b2dcc42bfa766583f8c9088b5ecb5c3
#   Stored in directory: /root/.cache/pip/wheels/89/3e/24/0f349c0b2eeb6965903035f3b00dbb5c9bea437b4a2f18d82c
# Successfully built fvcore iopath
# Installing collected packages: yacs, portalocker, iopath, fvcore, pytorch3d
# Successfully installed fvcore-0.1.5.post20221221 iopath-0.1.10 portalocker-2.7.0 pytorch3d-0.7.2 yacs-0.1.8

# %% [markdown]
# ## ShapeNet Terms and Conditions
#
# In order to be able to use the data, we agree the below terms and conditions:
#
# 1. Researcher shall use the Database only for non-commercial research and educational purposes.
# 2. Princeton University and Stanford University make no representations or warranties regarding the Database, including but not limited to warranties of non-infringement or fitness for a particular purpose.
# 3. Researcher accepts full responsibility for his or her use of the Database and shall defend and indemnify Princeton University and Stanford University, including their employees, Trustees, officers and agents, against any and all claims arising from Researcher's use of the Database, including but not limited to Researcher's use of any copies of copyrighted 3D models that he or she may create from the Database.
# 4. Researcher may provide research associates and colleagues with access to the Database provided that they first agree to be bound by these terms and conditions.
# 5. Princeton University and Stanford University reserve the right to terminate Researcher's access to the Database at any time.
# 6. If Researcher is employed by a for-profit, commercial entity, Researcher's employer shall also be bound by these terms and conditions, and Researcher hereby represents that he or she is fully authorized to enter into this agreement on behalf of such employer.
# 7. The law of the State of New Jersey shall apply to all disputes under this agreement.

# %% [markdown]
# ### Unzip ShapeNet pointcloud zip

# %%
# !unzip -q ./data/ShapeNet_pointclouds.zip -d ./data

# %% [markdown]
# ### Download 2D images

# %%
# !wget http://cvgl.stanford.edu/data2/ShapeNetRendering.tgz -P ./data
# Out:
# --2023-01-19 13:16:26--  http://cvgl.stanford.edu/data2/ShapeNetRendering.tgz
# Resolving cvgl.stanford.edu (cvgl.stanford.edu)... 171.64.64.64
# Connecting to cvgl.stanford.edu (cvgl.stanford.edu)|171.64.64.64|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cvgl.stanford.edu/data2/ShapeNetRendering.tgz [following]
# --2023-01-19 13:16:26--  https://cvgl.stanford.edu/data2/ShapeNetRendering.tgz
# Connecting to cvgl.stanford.edu (cvgl.stanford.edu)|171.64.64.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12318245442 (11G) [application/x-gzip]
# Saving to: ‘./data/ShapeNetRendering.tgz’
#
# ShapeNetRendering.t 100%[===================>]  11.47G  14.2MB/s    in 13m 46s
#
# 2023-01-19 13:30:13 (14.2 MB/s) - ‘./data/ShapeNetRendering.tgz’ saved [12318245442/12318245442]

# %%
# !tar -xf ./data/ShapeNetRendering.tgz -C ./data
#!rm /content/term-project/data/ShapeNetRendering.tgz

# %% [markdown]
# ### Construct ShapeNet dataset

# %%
from data.shapenet import ShapeNet

# Create a dataset with train split
train_dataset = ShapeNet('train')
val_dataset = ShapeNet('valid')
#overfit_dataset = ShapeNet('overfit')
test_dataset = ShapeNet('test')

# Get length, which is a call to __len__ function
print(f'Length of train set: {len(train_dataset)}') 
# Get length, which is a call to __len__ function
print(f'Length of val set: {len(val_dataset)}') 
# Get length, which is a call to __len__ function
print(f'Length of test set: {len(test_dataset)}')
# Out:
# Length of train set: 26271
# Length of val set: 8758
# Length of test set: 8755

# %%
from skimage.measure import marching_cubes

train_sample = train_dataset[1]
print(f'Input images: {train_sample["img"].shape}')  
print(f'Input point cloud: {train_sample["point"].shape}')
# Out:
# Input images: (3, 128, 128)
# Input point cloud: (2048, 3)

# %% [markdown]
# ### Print output shape of the 2D Encoder model (both variational and normal versions)

# %%
from model.model_2d import ImageEncoder
from torchsummary import summary

model2d_variational=ImageEncoder("variational",128)
model2d_variational.cuda()
input_tensor = torch.randn(1,3,128,128)
input_tensor=input_tensor.cuda()
print("input size:",input_tensor.size())


mu,std = model2d_variational(input_tensor)
print("Mu size:",mu.size(),"Std size:",std.size())
summary(model2d_variational,(3,128,128))
model2d_normal=ImageEncoder("normal",128)
model2d_normal.cuda()
latent=model2d_normal(input_tensor)
print("Latent shape:",latent.size())
# Out:
# input size: torch.Size([1, 3, 128, 128])
# Mu size: torch.Size([1, 128]) Std size: torch.Size([1, 128])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 128, 128]             896
#               ReLU-2         [-1, 32, 128, 128]               0
#             Conv2d-3         [-1, 32, 128, 128]           9,248
#               ReLU-4         [-1, 32, 128, 128]               0
#             Conv2d-5           [-1, 64, 63, 63]          18,496
#               ReLU-6           [-1, 64, 63, 63]               0
#             Conv2d-7           [-1, 64, 63, 63]          36,928
#               ReLU-8           [-1, 64, 63, 63]               0
#             Conv2d-9           [-1, 64, 63, 63]          36,928
#              ReLU-10           [-1, 64, 63, 63]               0
#            Conv2d-11          [-1, 128, 31, 31]          73,856
#              ReLU-12          [-1, 128, 31, 31]               0
#            Conv2d-13          [-1, 128, 31, 31]         147,584
#              ReLU-14          [-1, 128, 31, 31]               0
#            Conv2d-15          [-1, 128, 31, 31]         147,584
#              ReLU-16          [-1, 128, 31, 31]               0
#            Conv2d-17          [-1, 256, 15, 15]         295,168
#              ReLU-18          [-1, 256, 15, 15]               0
#            Conv2d-19          [-1, 256, 15, 15]         590,080
#              ReLU-20          [-1, 256, 15, 15]               0
#            Conv2d-21          [-1, 256, 15, 15]         590,080
#              ReLU-22          [-1, 256, 15, 15]               0
#            Conv2d-23            [-1, 512, 7, 7]       1,180,160
#              ReLU-24            [-1, 512, 7, 7]               0
#            Conv2d-25            [-1, 512, 7, 7]       2,359,808
#              ReLU-26            [-1, 512, 7, 7]               0
#            Conv2d-27            [-1, 512, 7, 7]       2,359,808
#              ReLU-28            [-1, 512, 7, 7]               0
#            Conv2d-29            [-1, 512, 7, 7]       2,359,808
#              ReLU-30            [-1, 512, 7, 7]               0
#            Conv2d-31            [-1, 512, 2, 2]       6,554,112
#            Linear-32                  [-1, 128]         262,272
#            Linear-33                  [-1, 128]         262,272
# ================================================================
# Total params: 17,285,088
# Trainable params: 17,285,088
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 37.44
# Params size (MB): 65.94
# Estimated Total Size (MB): 103.57
# ----------------------------------------------------------------
# Latent shape: torch.Size([1, 128])

# %% [markdown]
# ### Train 2D Encoder model to match the predicted latent space to the output of 3D Encoder of pointclouds

# %% [markdown]
# Normal, L1 loss

# %%
from training import train_2d_to_3d

generalization_config = {
    'experiment_name': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/2d_logs/normal/L1',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'bottleneck': 512,
    "cat":13,
    'batch_size': 32,
    "loss_criterion":"L1",
    "final_layer":"normal",
    "3d_encoder_path":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/logs/model_epoch_500.pth",
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    'max_epochs': 30,  
    'save_every_n': 1,
    'validate_every_n': 3,
    "autoencoder_bottleneck":512,
    "autoencoder_hidden_size":256,
    "autoencoder_output_size":2048*3,
    "alpha":None,
    "penalty_angle":None,
    "lambda":None


}

train_2d_to_3d.main(generalization_config)
# Out:
# Using device: cuda:0
#  initial input 512 initial hidden 256 initial output 6144
# Epoch 1/30 with iteration 100/19703: CD loss is 0.039313577115535736.
# Epoch 1/30 with iteration 200/19703: CD loss is 0.037083495408296585.
# Epoch 1/30 with iteration 300/19703: CD loss is 0.037841640412807465.
# Epoch 1/30 with iteration 400/19703: CD loss is 0.0334060862660408.
# Epoch 1/30 with iteration 500/19703: CD loss is 0.032961588352918625.
# Epoch 1/30 with iteration 600/19703: CD loss is 0.034095630049705505.
# Epoch 1/30 with iteration 700/19703: CD loss is 0.031010933220386505.
# Epoch 1/30 with iteration 800/19703: CD loss is 0.03032032772898674.
# Epoch 1/30 with iteration 900/19703: CD loss is 0.030697837471961975.
# Epoch 1/30 with iteration 1000/19703: CD loss is 0.029065262526273727.
# Epoch 1/30 with iteration 1100/19703: CD loss is 0.03389759361743927.
# Epoch 1/30 with iteration 1200/19703: CD loss is 0.028672736138105392.
# Epoch 1/30 with iteration 1300/19703: CD loss is 0.032780371606349945.
# Epoch 1/30 with iteration 1400/19703: CD loss is 0.03098825365304947.
# Epoch 1/30 with iteration 1500/19703: CD loss is 0.03312927484512329.
# Epoch 1/30 with iteration 1600/19703: CD loss is 0.0323767215013504.
# Epoch 1/30 with iteration 1700/19703: CD loss is 0.03434460610151291.
# Epoch 1/30 with iteration 1800/19703: CD loss is 0.029834913089871407.
# Epoch 1/30 with iteration 1900/19703: CD loss is 0.02875032275915146.
# Epoch 1/30 with iteration 2000/19703: CD loss is 0.029412701725959778.
# Epoch 1/30 with iteration 2100/19703: CD loss is 0.02810816839337349.
# Epoch 1/30 with iteration 2200/19703: CD loss is 0.029744664207100868.
# Epoch 1/30 with iteration 2300/19703: CD loss is 0.02342834137380123.
# Epoch 1/30 with iteration 2400/19703: CD loss is 0.025953134521842003.
# Epoch 1/30 with iteration 2500/19703: CD loss is 0.02951798588037491.
# Epoch 1/30 with iteration 2600/19703: CD loss is 0.02840842492878437.
# Epoch 1/30 with iteration 2700/19703: CD loss is 0.029447007924318314.
# Epoch 1/30 with iteration 2800/19703: CD loss is 0.027571408078074455.
# Epoch 1/30 with iteration 2900/19703: CD loss is 0.0303336288779974.
# Epoch 1/30 with iteration 3000/19703: CD loss is 0.026354428380727768.
# Epoch 1/30 with iteration 3100/19703: CD loss is 0.02562636323273182.
# Epoch 1/30 with iteration 3200/19703: CD loss is 0.030548065900802612.
# Epoch 1/30 with iteration 3300/19703: CD loss is 0.030515816062688828.
# Epoch 1/30 with iteration 3400/19703: CD loss is 0.027549047023057938.
# Epoch 1/30 with iteration 3500/19703: CD loss is 0.03041982650756836.
# Epoch 1/30 with iteration 3600/19703: CD loss is 0.028646577149629593.
# Epoch 1/30 with iteration 3700/19703: CD loss is 0.025504350662231445.
# Epoch 1/30 with iteration 3800/19703: CD loss is 0.025957126170396805.
# Epoch 1/30 with iteration 3900/19703: CD loss is 0.027558930218219757.
# Epoch 1/30 with iteration 4000/19703: CD loss is 0.027400188148021698.
# Epoch 1/30 with iteration 4100/19703: CD loss is 0.024072561413049698.
# Epoch 1/30 with iteration 4200/19703: CD loss is 0.026375023648142815.
# Epoch 1/30 with iteration 4300/19703: CD loss is 0.027027558535337448.
# Epoch 1/30 with iteration 4400/19703: CD loss is 0.026135988533496857.
# Epoch 1/30 with iteration 4500/19703: CD loss is 0.029938731342554092.
# Epoch 1/30 with iteration 4600/19703: CD loss is 0.025610502809286118.
# Epoch 1/30 with iteration 4700/19703: CD loss is 0.027636416256427765.
# Epoch 1/30 with iteration 4800/19703: CD loss is 0.02581091970205307.
# Epoch 1/30 with iteration 4900/19703: CD loss is 0.024350687861442566.
# Epoch 1/30 with iteration 5000/19703: CD loss is 0.026387959718704224.
# Epoch 1/30 with iteration 5100/19703: CD loss is 0.027771146968007088.
# Epoch 1/30 with iteration 5200/19703: CD loss is 0.025700420141220093.
# Epoch 1/30 with iteration 5300/19703: CD loss is 0.02307235263288021.
# Epoch 1/30 with iteration 5400/19703: CD loss is 0.024129625409841537.
# Epoch 1/30 with iteration 5500/19703: CD loss is 0.02269325777888298.
# Epoch 1/30 with iteration 5600/19703: CD loss is 0.025367960333824158.
# Epoch 1/30 with iteration 5700/19703: CD loss is 0.026960602030158043.
# Epoch 1/30 with iteration 5800/19703: CD loss is 0.024815334007143974.
# Epoch 1/30 with iteration 5900/19703: CD loss is 0.026269540190696716.
# Epoch 1/30 with iteration 6000/19703: CD loss is 0.031272947788238525.
# Epoch 1/30 with iteration 6100/19703: CD loss is 0.02369939535856247.
# Epoch 1/30 with iteration 6200/19703: CD loss is 0.024863408878445625.
# Epoch 1/30 with iteration 6300/19703: CD loss is 0.0258747860789299.
# Epoch 1/30 with iteration 6400/19703: CD loss is 0.02661089040338993.
# Epoch 1/30 with iteration 6500/19703: CD loss is 0.024683501571416855.
# Epoch 1/30 with iteration 6600/19703: CD loss is 0.025860348716378212.
# Epoch 1/30 with iteration 6700/19703: CD loss is 0.026467958465218544.
# Epoch 1/30 with iteration 6800/19703: CD loss is 0.02565571293234825.
# Epoch 1/30 with iteration 6900/19703: CD loss is 0.02322518453001976.
# Epoch 1/30 with iteration 7000/19703: CD loss is 0.024009713903069496.
# Epoch 1/30 with iteration 7100/19703: CD loss is 0.025566667318344116.
# Epoch 1/30 with iteration 7200/19703: CD loss is 0.024409689009189606.
# Epoch 1/30 with iteration 7300/19703: CD loss is 0.025908809155225754.
# Epoch 1/30 with iteration 7400/19703: CD loss is 0.026833992451429367.
# Epoch 1/30 with iteration 7500/19703: CD loss is 0.030506376177072525.
# Epoch 1/30 with iteration 7600/19703: CD loss is 0.023744024336338043.
# Epoch 1/30 with iteration 7700/19703: CD loss is 0.029112234711647034.
# Epoch 1/30 with iteration 7800/19703: CD loss is 0.024356845766305923.
# Epoch 1/30 with iteration 7900/19703: CD loss is 0.02856561541557312.
# Epoch 1/30 with iteration 8000/19703: CD loss is 0.02484627440571785.
# Epoch 1/30 with iteration 8100/19703: CD loss is 0.0250722486525774.
# Epoch 1/30 with iteration 8200/19703: CD loss is 0.024567116051912308.
# Epoch 1/30 with iteration 8300/19703: CD loss is 0.02280065044760704.
# Epoch 1/30 with iteration 8400/19703: CD loss is 0.02409103512763977.
# Epoch 1/30 with iteration 8500/19703: CD loss is 0.027671419084072113.
# Epoch 1/30 with iteration 8600/19703: CD loss is 0.02503836899995804.
# Epoch 1/30 with iteration 8700/19703: CD loss is 0.023870373144745827.
# Epoch 1/30 with iteration 8800/19703: CD loss is 0.02000763639807701.
# Epoch 1/30 with iteration 8900/19703: CD loss is 0.021395470947027206.
# Epoch 1/30 with iteration 9000/19703: CD loss is 0.02560468018054962.
# Epoch 1/30 with iteration 9100/19703: CD loss is 0.02715713158249855.
# Epoch 1/30 with iteration 9200/19703: CD loss is 0.0270797498524189.
# Epoch 1/30 with iteration 9300/19703: CD loss is 0.0298113152384758.
# Epoch 1/30 with iteration 9400/19703: CD loss is 0.022899076342582703.
# Epoch 1/30 with iteration 9500/19703: CD loss is 0.023888669908046722.
# Epoch 1/30 with iteration 9600/19703: CD loss is 0.02389887534081936.
# Epoch 1/30 with iteration 9700/19703: CD loss is 0.02196943387389183.
# Epoch 1/30 with iteration 9800/19703: CD loss is 0.02342662215232849.
# Epoch 1/30 with iteration 9900/19703: CD loss is 0.0264756977558136.
# Epoch 1/30 with iteration 10000/19703: CD loss is 0.021418249234557152.
# Epoch 1/30 with iteration 10100/19703: CD loss is 0.026767516508698463.
# Epoch 1/30 with iteration 10200/19703: CD loss is 0.025105178356170654.
# Epoch 1/30 with iteration 10300/19703: CD loss is 0.023314552381634712.
# Epoch 1/30 with iteration 10400/19703: CD loss is 0.023969169706106186.
# Epoch 1/30 with iteration 10500/19703: CD loss is 0.022971488535404205.
# Epoch 1/30 with iteration 10600/19703: CD loss is 0.025164660066366196.
# Epoch 1/30 with iteration 10700/19703: CD loss is 0.023942280560731888.
# Epoch 1/30 with iteration 10800/19703: CD loss is 0.024476969614624977.
# Epoch 1/30 with iteration 10900/19703: CD loss is 0.02366608940064907.
# Epoch 1/30 with iteration 11000/19703: CD loss is 0.024735039100050926.
# Epoch 1/30 with iteration 11100/19703: CD loss is 0.022318769246339798.
# Epoch 1/30 with iteration 11200/19703: CD loss is 0.022245224565267563.
# Epoch 1/30 with iteration 11300/19703: CD loss is 0.024261852726340294.
# Epoch 1/30 with iteration 11400/19703: CD loss is 0.02514532580971718.
# Epoch 1/30 with iteration 11500/19703: CD loss is 0.02408250980079174.
# Epoch 1/30 with iteration 11600/19703: CD loss is 0.024458393454551697.
# Epoch 1/30 with iteration 11700/19703: CD loss is 0.0267077274620533.
# Epoch 1/30 with iteration 11800/19703: CD loss is 0.027042655274271965.
# Epoch 1/30 with iteration 11900/19703: CD loss is 0.027757005766034126.
# Epoch 1/30 with iteration 12000/19703: CD loss is 0.025407493114471436.
# Epoch 1/30 with iteration 12100/19703: CD loss is 0.022869113832712173.
# Epoch 1/30 with iteration 12200/19703: CD loss is 0.0266078133136034.
# Epoch 1/30 with iteration 12300/19703: CD loss is 0.02346237376332283.
# Epoch 1/30 with iteration 12400/19703: CD loss is 0.0224054753780365.
# Epoch 1/30 with iteration 12500/19703: CD loss is 0.022394288331270218.
# Epoch 1/30 with iteration 12600/19703: CD loss is 0.022875098511576653.
# Epoch 1/30 with iteration 12700/19703: CD loss is 0.02493693307042122.
# Epoch 1/30 with iteration 12800/19703: CD loss is 0.02208433672785759.
# Epoch 1/30 with iteration 12900/19703: CD loss is 0.02374686300754547.
# Epoch 1/30 with iteration 13000/19703: CD loss is 0.024796200916171074.
# Epoch 1/30 with iteration 13100/19703: CD loss is 0.02283279411494732.
# Epoch 1/30 with iteration 13200/19703: CD loss is 0.025789448991417885.
# Epoch 1/30 with iteration 13300/19703: CD loss is 0.023899395018815994.
# Epoch 1/30 with iteration 13400/19703: CD loss is 0.025069352239370346.
# Epoch 1/30 with iteration 13500/19703: CD loss is 0.024592150002717972.
# Epoch 1/30 with iteration 13600/19703: CD loss is 0.022620901465415955.
# Epoch 1/30 with iteration 13700/19703: CD loss is 0.025697879493236542.
# Epoch 1/30 with iteration 13800/19703: CD loss is 0.024850811809301376.
# Epoch 1/30 with iteration 13900/19703: CD loss is 0.024448266252875328.
# Epoch 1/30 with iteration 14000/19703: CD loss is 0.02384628728032112.
# Epoch 1/30 with iteration 14100/19703: CD loss is 0.021594375371932983.
# Epoch 1/30 with iteration 14200/19703: CD loss is 0.023448321968317032.
# Epoch 1/30 with iteration 14300/19703: CD loss is 0.028633305802941322.
# Epoch 1/30 with iteration 14400/19703: CD loss is 0.019892489537596703.
# Epoch 1/30 with iteration 14500/19703: CD loss is 0.02267620339989662.
# Epoch 1/30 with iteration 14600/19703: CD loss is 0.02387988194823265.
# Epoch 1/30 with iteration 14700/19703: CD loss is 0.020311666652560234.
# Epoch 1/30 with iteration 14800/19703: CD loss is 0.026676129549741745.
# Epoch 1/30 with iteration 14900/19703: CD loss is 0.021211886778473854.
# Epoch 1/30 with iteration 15000/19703: CD loss is 0.026792939752340317.
# Epoch 1/30 with iteration 15100/19703: CD loss is 0.024003375321626663.
# Epoch 1/30 with iteration 15200/19703: CD loss is 0.028395652770996094.
# Epoch 1/30 with iteration 15300/19703: CD loss is 0.024643614888191223.
# Epoch 1/30 with iteration 15400/19703: CD loss is 0.025768911466002464.
# Epoch 1/30 with iteration 15500/19703: CD loss is 0.025835055857896805.
# Epoch 1/30 with iteration 15600/19703: CD loss is 0.023335617035627365.
# Epoch 1/30 with iteration 15700/19703: CD loss is 0.023743294179439545.
# Epoch 1/30 with iteration 15800/19703: CD loss is 0.021767307072877884.
# Epoch 1/30 with iteration 15900/19703: CD loss is 0.0205925814807415.
# Epoch 1/30 with iteration 16000/19703: CD loss is 0.024634454399347305.
# Epoch 1/30 with iteration 16100/19703: CD loss is 0.023694295436143875.
# Epoch 1/30 with iteration 16200/19703: CD loss is 0.021416105329990387.
# Epoch 1/30 with iteration 16300/19703: CD loss is 0.02702220156788826.
# Epoch 1/30 with iteration 16400/19703: CD loss is 0.025868277996778488.
# Epoch 1/30 with iteration 16500/19703: CD loss is 0.021734569221735.
# Epoch 1/30 with iteration 16600/19703: CD loss is 0.025311097502708435.
# Epoch 1/30 with iteration 16700/19703: CD loss is 0.025321612134575844.
# Epoch 1/30 with iteration 16800/19703: CD loss is 0.021982021629810333.
# Epoch 1/30 with iteration 16900/19703: CD loss is 0.025369197130203247.
# Epoch 1/30 with iteration 17000/19703: CD loss is 0.021411046385765076.
# Epoch 1/30 with iteration 17100/19703: CD loss is 0.020743325352668762.
# Epoch 1/30 with iteration 17200/19703: CD loss is 0.02404472790658474.
# Epoch 1/30 with iteration 17300/19703: CD loss is 0.02123868279159069.
# Epoch 1/30 with iteration 17400/19703: CD loss is 0.02029252052307129.
# Epoch 1/30 with iteration 17500/19703: CD loss is 0.024985164403915405.
# Epoch 1/30 with iteration 17600/19703: CD loss is 0.019994724541902542.
# Epoch 1/30 with iteration 17700/19703: CD loss is 0.02414644882082939.
# Epoch 1/30 with iteration 17800/19703: CD loss is 0.027640070766210556.
# Epoch 1/30 with iteration 17900/19703: CD loss is 0.0241050124168396.
# Epoch 1/30 with iteration 18000/19703: CD loss is 0.022116389125585556.
# Epoch 1/30 with iteration 18100/19703: CD loss is 0.02405407838523388.
# Epoch 1/30 with iteration 18200/19703: CD loss is 0.02653062529861927.
# Epoch 1/30 with iteration 18300/19703: CD loss is 0.021448705345392227.
# Epoch 1/30 with iteration 18400/19703: CD loss is 0.023345883935689926.
# Epoch 1/30 with iteration 18500/19703: CD loss is 0.024104785174131393.
# Epoch 1/30 with iteration 18600/19703: CD loss is 0.02553204819560051.
# Epoch 1/30 with iteration 18700/19703: CD loss is 0.02704380825161934.
# Epoch 1/30 with iteration 18800/19703: CD loss is 0.023342929780483246.
# Epoch 1/30 with iteration 18900/19703: CD loss is 0.02293124794960022.
# Epoch 1/30 with iteration 19000/19703: CD loss is 0.023914147168397903.
# Epoch 1/30 with iteration 19100/19703: CD loss is 0.021194707602262497.
# Epoch 1/30 with iteration 19200/19703: CD loss is 0.021812137216329575.
# Epoch 1/30 with iteration 19300/19703: CD loss is 0.02192387357354164.
# Epoch 1/30 with iteration 19400/19703: CD loss is 0.02268132194876671.
# Epoch 1/30 with iteration 19500/19703: CD loss is 0.023018475621938705.
# Epoch 1/30 with iteration 19600/19703: CD loss is 0.022770557552576065.
# Epoch 1/30 with iteration 19700/19703: CD loss is 0.022361088544130325.
# [001/19703] train loss: 510.80876365303993
# Epoch 2/30 with iteration 100/19703: CD loss is 0.021084245294332504.
# Epoch 2/30 with iteration 200/19703: CD loss is 0.02271133102476597.
# Epoch 2/30 with iteration 300/19703: CD loss is 0.02233555167913437.
# Epoch 2/30 with iteration 400/19703: CD loss is 0.02225588634610176.
# Epoch 2/30 with iteration 500/19703: CD loss is 0.022145455703139305.
# Epoch 2/30 with iteration 600/19703: CD loss is 0.021830443292856216.
# Epoch 2/30 with iteration 700/19703: CD loss is 0.021801117807626724.
# Epoch 2/30 with iteration 800/19703: CD loss is 0.022554414346814156.
# Epoch 2/30 with iteration 900/19703: CD loss is 0.024344034492969513.
# Epoch 2/30 with iteration 1000/19703: CD loss is 0.02327927201986313.
# Epoch 2/30 with iteration 1100/19703: CD loss is 0.02186446264386177.
# Epoch 2/30 with iteration 1200/19703: CD loss is 0.024717628955841064.
# Epoch 2/30 with iteration 1300/19703: CD loss is 0.023024430498480797.
# Epoch 2/30 with iteration 1400/19703: CD loss is 0.02900192141532898.
# Epoch 2/30 with iteration 1500/19703: CD loss is 0.02316584624350071.
# Epoch 2/30 with iteration 1600/19703: CD loss is 0.021149983629584312.
# Epoch 2/30 with iteration 1700/19703: CD loss is 0.025099974125623703.
# Epoch 2/30 with iteration 1800/19703: CD loss is 0.02741527557373047.
# Epoch 2/30 with iteration 1900/19703: CD loss is 0.020635481923818588.
# Epoch 2/30 with iteration 2000/19703: CD loss is 0.025673210620880127.
# Epoch 2/30 with iteration 2100/19703: CD loss is 0.021621745079755783.
# Epoch 2/30 with iteration 2200/19703: CD loss is 0.022104337811470032.
# Epoch 2/30 with iteration 2300/19703: CD loss is 0.023708458989858627.
# Epoch 2/30 with iteration 2400/19703: CD loss is 0.022228702902793884.
# Epoch 2/30 with iteration 2500/19703: CD loss is 0.023697983473539352.
# Epoch 2/30 with iteration 2600/19703: CD loss is 0.021909046918153763.
# Epoch 2/30 with iteration 2700/19703: CD loss is 0.02402319386601448.
# Epoch 2/30 with iteration 2800/19703: CD loss is 0.023264914751052856.
# Epoch 2/30 with iteration 2900/19703: CD loss is 0.018900925293564796.
# Epoch 2/30 with iteration 3000/19703: CD loss is 0.025265753269195557.
# Epoch 2/30 with iteration 3100/19703: CD loss is 0.025575026869773865.
# Epoch 2/30 with iteration 3200/19703: CD loss is 0.018989212810993195.
# Epoch 2/30 with iteration 3300/19703: CD loss is 0.025165271013975143.
# Epoch 2/30 with iteration 3400/19703: CD loss is 0.02278374508023262.
# Epoch 2/30 with iteration 3500/19703: CD loss is 0.021188240498304367.
# Epoch 2/30 with iteration 3600/19703: CD loss is 0.027301570400595665.
# Epoch 2/30 with iteration 3700/19703: CD loss is 0.023437365889549255.
# Epoch 2/30 with iteration 3800/19703: CD loss is 0.02162313275039196.
# Epoch 2/30 with iteration 3900/19703: CD loss is 0.02502296306192875.
# Epoch 2/30 with iteration 4000/19703: CD loss is 0.020875584334135056.
# Epoch 2/30 with iteration 4100/19703: CD loss is 0.02620295248925686.
# Epoch 2/30 with iteration 4200/19703: CD loss is 0.02155960351228714.
# Epoch 2/30 with iteration 4300/19703: CD loss is 0.02093498408794403.
# Epoch 2/30 with iteration 4400/19703: CD loss is 0.022617559880018234.
# Epoch 2/30 with iteration 4500/19703: CD loss is 0.023731190711259842.
# Epoch 2/30 with iteration 4600/19703: CD loss is 0.025888554751873016.
# Epoch 2/30 with iteration 4700/19703: CD loss is 0.021019864827394485.
# Epoch 2/30 with iteration 4800/19703: CD loss is 0.023506980389356613.
# Epoch 2/30 with iteration 4900/19703: CD loss is 0.021781081333756447.
# Epoch 2/30 with iteration 5000/19703: CD loss is 0.0257999487221241.
# Epoch 2/30 with iteration 5100/19703: CD loss is 0.025735437870025635.
# Epoch 2/30 with iteration 5200/19703: CD loss is 0.020259348675608635.
# Epoch 2/30 with iteration 5300/19703: CD loss is 0.021315984427928925.
# Epoch 2/30 with iteration 5400/19703: CD loss is 0.02557089738547802.
# Epoch 2/30 with iteration 5500/19703: CD loss is 0.021418068557977676.
# Epoch 2/30 with iteration 5600/19703: CD loss is 0.02375386282801628.
# Epoch 2/30 with iteration 5700/19703: CD loss is 0.028475705534219742.
# Epoch 2/30 with iteration 5800/19703: CD loss is 0.021716739982366562.
# Epoch 2/30 with iteration 5900/19703: CD loss is 0.01993117667734623.
# Epoch 2/30 with iteration 6000/19703: CD loss is 0.023027634248137474.
# Epoch 2/30 with iteration 6100/19703: CD loss is 0.023193713277578354.
# Epoch 2/30 with iteration 6200/19703: CD loss is 0.02129785716533661.
# Epoch 2/30 with iteration 6300/19703: CD loss is 0.021428963169455528.
# Epoch 2/30 with iteration 6400/19703: CD loss is 0.021418072283267975.
# Epoch 2/30 with iteration 6500/19703: CD loss is 0.022081147879362106.
# Epoch 2/30 with iteration 6600/19703: CD loss is 0.02252197451889515.
# Epoch 2/30 with iteration 6700/19703: CD loss is 0.0208577997982502.
# Epoch 2/30 with iteration 6800/19703: CD loss is 0.023193594068288803.
# Epoch 2/30 with iteration 6900/19703: CD loss is 0.020097307860851288.
# Epoch 2/30 with iteration 7000/19703: CD loss is 0.019247647374868393.
# Epoch 2/30 with iteration 7100/19703: CD loss is 0.02502945438027382.
# Epoch 2/30 with iteration 7200/19703: CD loss is 0.02091490477323532.
# Epoch 2/30 with iteration 7300/19703: CD loss is 0.0234021358191967.
# Epoch 2/30 with iteration 7400/19703: CD loss is 0.02560489997267723.
# Epoch 2/30 with iteration 7500/19703: CD loss is 0.031610120087862015.
# Epoch 2/30 with iteration 7600/19703: CD loss is 0.025347160175442696.
# Epoch 2/30 with iteration 7700/19703: CD loss is 0.02472652867436409.
# Epoch 2/30 with iteration 7800/19703: CD loss is 0.021083321422338486.
# Epoch 2/30 with iteration 7900/19703: CD loss is 0.023515943437814713.
# Epoch 2/30 with iteration 8000/19703: CD loss is 0.02243535965681076.
# Epoch 2/30 with iteration 8100/19703: CD loss is 0.020535040646791458.
# Epoch 2/30 with iteration 8200/19703: CD loss is 0.025511862710118294.
# Epoch 2/30 with iteration 8300/19703: CD loss is 0.0233469121158123.
# Epoch 2/30 with iteration 8400/19703: CD loss is 0.02095130831003189.
# Epoch 2/30 with iteration 8500/19703: CD loss is 0.023441653698682785.
# Epoch 2/30 with iteration 8600/19703: CD loss is 0.022303586825728416.
# Epoch 2/30 with iteration 8700/19703: CD loss is 0.02224310114979744.
# Epoch 2/30 with iteration 8800/19703: CD loss is 0.020620737224817276.
# Epoch 2/30 with iteration 8900/19703: CD loss is 0.024558447301387787.
# Epoch 2/30 with iteration 9000/19703: CD loss is 0.021908968687057495.
# Epoch 2/30 with iteration 9100/19703: CD loss is 0.02406047284603119.
# Epoch 2/30 with iteration 9200/19703: CD loss is 0.02490054816007614.
# Epoch 2/30 with iteration 9300/19703: CD loss is 0.02181023173034191.
# Epoch 2/30 with iteration 9400/19703: CD loss is 0.022211745381355286.
# Epoch 2/30 with iteration 9500/19703: CD loss is 0.02494381181895733.
# Epoch 2/30 with iteration 9600/19703: CD loss is 0.021190259605646133.
# Epoch 2/30 with iteration 9700/19703: CD loss is 0.022623013705015182.
# Epoch 2/30 with iteration 9800/19703: CD loss is 0.02166152000427246.
# Epoch 2/30 with iteration 9900/19703: CD loss is 0.02257624827325344.
# Epoch 2/30 with iteration 10000/19703: CD loss is 0.022539444267749786.
# Epoch 2/30 with iteration 10100/19703: CD loss is 0.025821730494499207.
# Epoch 2/30 with iteration 10200/19703: CD loss is 0.0214631799608469.
# Epoch 2/30 with iteration 10300/19703: CD loss is 0.02439199760556221.
# Epoch 2/30 with iteration 10400/19703: CD loss is 0.019493117928504944.
# Epoch 2/30 with iteration 10500/19703: CD loss is 0.022976068779826164.
# Epoch 2/30 with iteration 10600/19703: CD loss is 0.020002281293272972.
# Epoch 2/30 with iteration 10700/19703: CD loss is 0.02007807046175003.
# Epoch 2/30 with iteration 10800/19703: CD loss is 0.023466860875487328.
# Epoch 2/30 with iteration 10900/19703: CD loss is 0.020580140873789787.
# Epoch 2/30 with iteration 11000/19703: CD loss is 0.02238478511571884.
# Epoch 2/30 with iteration 11100/19703: CD loss is 0.02120397426187992.
# Epoch 2/30 with iteration 11200/19703: CD loss is 0.02198105677962303.
# Epoch 2/30 with iteration 11300/19703: CD loss is 0.02218654938042164.
# Epoch 2/30 with iteration 11400/19703: CD loss is 0.020461829379200935.
# Epoch 2/30 with iteration 11500/19703: CD loss is 0.022639498114585876.
# Epoch 2/30 with iteration 11600/19703: CD loss is 0.02060532569885254.
# Epoch 2/30 with iteration 11700/19703: CD loss is 0.020827416330575943.
# Epoch 2/30 with iteration 11800/19703: CD loss is 0.023241927847266197.
# Epoch 2/30 with iteration 11900/19703: CD loss is 0.021517299115657806.
# Epoch 2/30 with iteration 12000/19703: CD loss is 0.022711992263793945.
# Epoch 2/30 with iteration 12100/19703: CD loss is 0.02072199061512947.
# Epoch 2/30 with iteration 12200/19703: CD loss is 0.024148590862751007.
# Epoch 2/30 with iteration 12300/19703: CD loss is 0.023995086550712585.
# Epoch 2/30 with iteration 12400/19703: CD loss is 0.02533760666847229.
# Epoch 2/30 with iteration 12500/19703: CD loss is 0.02239152230322361.
# Epoch 2/30 with iteration 12600/19703: CD loss is 0.02420499175786972.
# Epoch 2/30 with iteration 12700/19703: CD loss is 0.02166934125125408.
# Epoch 2/30 with iteration 12800/19703: CD loss is 0.01893349550664425.
# Epoch 2/30 with iteration 12900/19703: CD loss is 0.022415539249777794.
# Epoch 2/30 with iteration 13000/19703: CD loss is 0.021255740895867348.
# Epoch 2/30 with iteration 13100/19703: CD loss is 0.019973687827587128.
# Epoch 2/30 with iteration 13200/19703: CD loss is 0.021007291972637177.
# Epoch 2/30 with iteration 13300/19703: CD loss is 0.025192316621541977.
# Epoch 2/30 with iteration 13400/19703: CD loss is 0.022086933255195618.
# Epoch 2/30 with iteration 13500/19703: CD loss is 0.023377832025289536.
# Epoch 2/30 with iteration 13600/19703: CD loss is 0.02002399042248726.
# Epoch 2/30 with iteration 13700/19703: CD loss is 0.020327415317296982.
# Epoch 2/30 with iteration 13800/19703: CD loss is 0.024253956973552704.
# Epoch 2/30 with iteration 13900/19703: CD loss is 0.02113795280456543.
# Epoch 2/30 with iteration 14000/19703: CD loss is 0.021167119964957237.
# Epoch 2/30 with iteration 14100/19703: CD loss is 0.02500074729323387.
# Epoch 2/30 with iteration 14200/19703: CD loss is 0.025361523032188416.
# Epoch 2/30 with iteration 14300/19703: CD loss is 0.02425038442015648.
# Epoch 2/30 with iteration 14400/19703: CD loss is 0.027255073189735413.
# Epoch 2/30 with iteration 14500/19703: CD loss is 0.021346209570765495.
# Epoch 2/30 with iteration 14600/19703: CD loss is 0.021866193041205406.
# Epoch 2/30 with iteration 14700/19703: CD loss is 0.02150883898139.
# Epoch 2/30 with iteration 14800/19703: CD loss is 0.021773982793092728.
# Epoch 2/30 with iteration 14900/19703: CD loss is 0.02377932146191597.
# Epoch 2/30 with iteration 15000/19703: CD loss is 0.024365218356251717.
# Epoch 2/30 with iteration 15100/19703: CD loss is 0.024975262582302094.
# Epoch 2/30 with iteration 15200/19703: CD loss is 0.023528996855020523.
# Epoch 2/30 with iteration 15300/19703: CD loss is 0.023732993751764297.
# Epoch 2/30 with iteration 15400/19703: CD loss is 0.022098038345575333.
# Epoch 2/30 with iteration 15500/19703: CD loss is 0.026441721245646477.
# Epoch 2/30 with iteration 15600/19703: CD loss is 0.024230636656284332.
# Epoch 2/30 with iteration 15700/19703: CD loss is 0.024069558829069138.
# Epoch 2/30 with iteration 15800/19703: CD loss is 0.021944409236311913.
# Epoch 2/30 with iteration 15900/19703: CD loss is 0.02053404413163662.
# Epoch 2/30 with iteration 16000/19703: CD loss is 0.021413441747426987.
# Epoch 2/30 with iteration 16100/19703: CD loss is 0.02372071146965027.
# Epoch 2/30 with iteration 16200/19703: CD loss is 0.021292082965373993.
# Epoch 2/30 with iteration 16300/19703: CD loss is 0.0217299684882164.
# Epoch 2/30 with iteration 16400/19703: CD loss is 0.02103385329246521.
# Epoch 2/30 with iteration 16500/19703: CD loss is 0.023978907614946365.
# Epoch 2/30 with iteration 16600/19703: CD loss is 0.021563531830906868.
# Epoch 2/30 with iteration 16700/19703: CD loss is 0.02399362251162529.
# Epoch 2/30 with iteration 16800/19703: CD loss is 0.020371321588754654.
# Epoch 2/30 with iteration 16900/19703: CD loss is 0.024260414764285088.
# Epoch 2/30 with iteration 17000/19703: CD loss is 0.0229545459151268.
# Epoch 2/30 with iteration 17100/19703: CD loss is 0.021470122039318085.
# Epoch 2/30 with iteration 17200/19703: CD loss is 0.025455111637711525.
# Epoch 2/30 with iteration 17300/19703: CD loss is 0.021165454760193825.
# Epoch 2/30 with iteration 17400/19703: CD loss is 0.023297496140003204.
# Epoch 2/30 with iteration 17500/19703: CD loss is 0.02298464998602867.
# Epoch 2/30 with iteration 17600/19703: CD loss is 0.01935780979692936.
# Epoch 2/30 with iteration 17700/19703: CD loss is 0.02116425894200802.
# Epoch 2/30 with iteration 17800/19703: CD loss is 0.0217647273093462.
# Epoch 2/30 with iteration 17900/19703: CD loss is 0.022116007283329964.
# Epoch 2/30 with iteration 18000/19703: CD loss is 0.020057417452335358.
# Epoch 2/30 with iteration 18100/19703: CD loss is 0.02259550243616104.
# Epoch 2/30 with iteration 18200/19703: CD loss is 0.022452451288700104.
# Epoch 2/30 with iteration 18300/19703: CD loss is 0.024524297565221786.
# Epoch 2/30 with iteration 18400/19703: CD loss is 0.020360158756375313.
# Epoch 2/30 with iteration 18500/19703: CD loss is 0.02278687059879303.
# Epoch 2/30 with iteration 18600/19703: CD loss is 0.0226906705647707.
# Epoch 2/30 with iteration 18700/19703: CD loss is 0.021360136568546295.
# Epoch 2/30 with iteration 18800/19703: CD loss is 0.027126941829919815.
# Epoch 2/30 with iteration 18900/19703: CD loss is 0.01958857662975788.
# Epoch 2/30 with iteration 19000/19703: CD loss is 0.024243468418717384.
# Epoch 2/30 with iteration 19100/19703: CD loss is 0.02291048876941204.
# Epoch 2/30 with iteration 19200/19703: CD loss is 0.01897771842777729.
# Epoch 2/30 with iteration 19300/19703: CD loss is 0.02112783119082451.
# Epoch 2/30 with iteration 19400/19703: CD loss is 0.024255815893411636.
# Epoch 2/30 with iteration 19500/19703: CD loss is 0.021040689200162888.
# Epoch 2/30 with iteration 19600/19703: CD loss is 0.023182787001132965.
# Epoch 2/30 with iteration 19700/19703: CD loss is 0.02144370786845684.
# [002/19703] train loss: 443.1669698636979
# Epoch 3/30 with iteration 100/19703: CD loss is 0.02151579037308693.
# Epoch 3/30 with iteration 200/19703: CD loss is 0.02067907527089119.
# Epoch 3/30 with iteration 300/19703: CD loss is 0.02221253328025341.
# Epoch 3/30 with iteration 400/19703: CD loss is 0.022354938089847565.
# Epoch 3/30 with iteration 500/19703: CD loss is 0.019649649038910866.
# Epoch 3/30 with iteration 600/19703: CD loss is 0.02003675326704979.
# Epoch 3/30 with iteration 700/19703: CD loss is 0.023894652724266052.
# Epoch 3/30 with iteration 800/19703: CD loss is 0.021125828847289085.
# Epoch 3/30 with iteration 900/19703: CD loss is 0.02397075667977333.
# Epoch 3/30 with iteration 1000/19703: CD loss is 0.022262874990701675.
# Epoch 3/30 with iteration 1100/19703: CD loss is 0.02016088366508484.
# Epoch 3/30 with iteration 1200/19703: CD loss is 0.02272401750087738.
# Epoch 3/30 with iteration 1300/19703: CD loss is 0.02449759840965271.
# Epoch 3/30 with iteration 1400/19703: CD loss is 0.023897916078567505.
# Epoch 3/30 with iteration 1500/19703: CD loss is 0.022171664983034134.
# Epoch 3/30 with iteration 1600/19703: CD loss is 0.02074618637561798.
# Epoch 3/30 with iteration 1700/19703: CD loss is 0.01904641091823578.
# Epoch 3/30 with iteration 1800/19703: CD loss is 0.021898120641708374.
# Epoch 3/30 with iteration 1900/19703: CD loss is 0.020740419626235962.
# Epoch 3/30 with iteration 2000/19703: CD loss is 0.02090873010456562.
# Epoch 3/30 with iteration 2100/19703: CD loss is 0.022405922412872314.
# Epoch 3/30 with iteration 2200/19703: CD loss is 0.020837364718317986.
# Epoch 3/30 with iteration 2300/19703: CD loss is 0.018466033041477203.
# Epoch 3/30 with iteration 2400/19703: CD loss is 0.023720616474747658.
# Epoch 3/30 with iteration 2500/19703: CD loss is 0.023313237354159355.
# Epoch 3/30 with iteration 2600/19703: CD loss is 0.022874008864164352.
# Epoch 3/30 with iteration 2700/19703: CD loss is 0.027059456333518028.
# Epoch 3/30 with iteration 2800/19703: CD loss is 0.02808167226612568.
# Epoch 3/30 with iteration 2900/19703: CD loss is 0.02371320128440857.
# Epoch 3/30 with iteration 3000/19703: CD loss is 0.02231011539697647.
# Epoch 3/30 with iteration 3100/19703: CD loss is 0.024130068719387054.
# Epoch 3/30 with iteration 3200/19703: CD loss is 0.021709691733121872.
# Epoch 3/30 with iteration 3300/19703: CD loss is 0.017906516790390015.
# Epoch 3/30 with iteration 3400/19703: CD loss is 0.022889822721481323.
# Epoch 3/30 with iteration 3500/19703: CD loss is 0.0219777449965477.
# Epoch 3/30 with iteration 3600/19703: CD loss is 0.021942058578133583.
# Epoch 3/30 with iteration 3700/19703: CD loss is 0.02230469323694706.
# Epoch 3/30 with iteration 3800/19703: CD loss is 0.01813890039920807.
# Epoch 3/30 with iteration 3900/19703: CD loss is 0.02498026192188263.
# Epoch 3/30 with iteration 4000/19703: CD loss is 0.02400931343436241.
# Epoch 3/30 with iteration 4100/19703: CD loss is 0.01959986798465252.
# Epoch 3/30 with iteration 4200/19703: CD loss is 0.02385576069355011.
# Epoch 3/30 with iteration 4300/19703: CD loss is 0.02435728907585144.
# Epoch 3/30 with iteration 4400/19703: CD loss is 0.02322050929069519.
# Epoch 3/30 with iteration 4500/19703: CD loss is 0.02207804098725319.
# Epoch 3/30 with iteration 4600/19703: CD loss is 0.02222689427435398.
# Epoch 3/30 with iteration 4700/19703: CD loss is 0.02420237846672535.
# Epoch 3/30 with iteration 4800/19703: CD loss is 0.02302934229373932.
# Epoch 3/30 with iteration 4900/19703: CD loss is 0.02357025071978569.
# Epoch 3/30 with iteration 5000/19703: CD loss is 0.021982820704579353.
# Epoch 3/30 with iteration 5100/19703: CD loss is 0.02198978327214718.
# Epoch 3/30 with iteration 5200/19703: CD loss is 0.026777707040309906.
# Epoch 3/30 with iteration 5300/19703: CD loss is 0.01887723058462143.
# Epoch 3/30 with iteration 5400/19703: CD loss is 0.019343962892889977.
# Epoch 3/30 with iteration 5500/19703: CD loss is 0.01974566839635372.
# Epoch 3/30 with iteration 5600/19703: CD loss is 0.02085520699620247.
# Epoch 3/30 with iteration 5700/19703: CD loss is 0.019433867186307907.
# Epoch 3/30 with iteration 5800/19703: CD loss is 0.02287248894572258.
# Epoch 3/30 with iteration 5900/19703: CD loss is 0.02551056444644928.
# Epoch 3/30 with iteration 6000/19703: CD loss is 0.020965255796909332.
# Epoch 3/30 with iteration 6100/19703: CD loss is 0.022926712408661842.
# Epoch 3/30 with iteration 6200/19703: CD loss is 0.021625429391860962.
# Epoch 3/30 with iteration 6300/19703: CD loss is 0.02111716940999031.
# Epoch 3/30 with iteration 6400/19703: CD loss is 0.019418679177761078.
# Epoch 3/30 with iteration 6500/19703: CD loss is 0.024013034999370575.
# Epoch 3/30 with iteration 6600/19703: CD loss is 0.018407927826046944.
# Epoch 3/30 with iteration 6700/19703: CD loss is 0.02130535989999771.
# Epoch 3/30 with iteration 6800/19703: CD loss is 0.020232759416103363.
# Epoch 3/30 with iteration 6900/19703: CD loss is 0.02141662687063217.
# Epoch 3/30 with iteration 7000/19703: CD loss is 0.021896880120038986.
# Epoch 3/30 with iteration 7100/19703: CD loss is 0.020043108612298965.
# Epoch 3/30 with iteration 7200/19703: CD loss is 0.0207707230001688.
# Epoch 3/30 with iteration 7300/19703: CD loss is 0.020143985748291016.
# Epoch 3/30 with iteration 7400/19703: CD loss is 0.019856635481119156.
# Epoch 3/30 with iteration 7500/19703: CD loss is 0.022701172158122063.
# Epoch 3/30 with iteration 7600/19703: CD loss is 0.02469879947602749.
# Epoch 3/30 with iteration 7700/19703: CD loss is 0.022131163626909256.
# Epoch 3/30 with iteration 7800/19703: CD loss is 0.023200714960694313.
# Epoch 3/30 with iteration 7900/19703: CD loss is 0.022026129066944122.
# Epoch 3/30 with iteration 8000/19703: CD loss is 0.020682817324995995.
# Epoch 3/30 with iteration 8100/19703: CD loss is 0.020152339711785316.
# Epoch 3/30 with iteration 8200/19703: CD loss is 0.02267465740442276.
# Epoch 3/30 with iteration 8300/19703: CD loss is 0.019802002236247063.
# Epoch 3/30 with iteration 8400/19703: CD loss is 0.017312481999397278.
# Epoch 3/30 with iteration 8500/19703: CD loss is 0.021168621256947517.
# Epoch 3/30 with iteration 8600/19703: CD loss is 0.02059035748243332.
# Epoch 3/30 with iteration 8700/19703: CD loss is 0.02284681610763073.
# Epoch 3/30 with iteration 8800/19703: CD loss is 0.022113606333732605.
# Epoch 3/30 with iteration 8900/19703: CD loss is 0.02214588038623333.
# Epoch 3/30 with iteration 9000/19703: CD loss is 0.018059980124235153.
# Epoch 3/30 with iteration 9100/19703: CD loss is 0.02265753597021103.
# Epoch 3/30 with iteration 9200/19703: CD loss is 0.02126273885369301.
# Epoch 3/30 with iteration 9300/19703: CD loss is 0.021795906126499176.
# Epoch 3/30 with iteration 9400/19703: CD loss is 0.019958456978201866.
# Epoch 3/30 with iteration 9500/19703: CD loss is 0.022654129192233086.
# Epoch 3/30 with iteration 9600/19703: CD loss is 0.022456180304288864.
# Epoch 3/30 with iteration 9700/19703: CD loss is 0.02161342278122902.
# Epoch 3/30 with iteration 9800/19703: CD loss is 0.023226598277688026.
# Epoch 3/30 with iteration 9900/19703: CD loss is 0.02123149298131466.

# %% [markdown]
# Normal, L2 loss

# %%
from training import train_2d_to_3d

generalization_config = {
    'experiment_name': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/2d_logs/normal/L2',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'bottleneck': 512,
    "cat":13,
    'batch_size': 32,
    "loss_criterion":"L2",
    "final_layer":"normal",
    "3d_encoder_path":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/logs/model_epoch_500.pth",
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    'max_epochs': 30,  
    'save_every_n': 1,
    'validate_every_n': 5,
    "autoencoder_bottleneck":512,
    "autoencoder_hidden_size":256,
    "autoencoder_output_size":2048*3,
    "alpha":None,
    "penalty_angle":None,
    "lambda":None


}

train_2d_to_3d.main(generalization_config)

# %% [markdown]
# Variational

# %%
from training import train_2d_to_3d

generalization_config = {
    'experiment_name': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/2d_logs/variational',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'bottleneck': 512,
    "cat":13,
    'batch_size': 32,
    "loss_criterion":"variational",
    "final_layer":"variational",
    "3d_encoder_path":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/logs/model_epoch_500.pth",
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    'max_epochs': 30,  
    'save_every_n': 1,
    'validate_every_n': 3,
    "autoencoder_bottleneck":512,
    "autoencoder_hidden_size":256,
    "autoencoder_output_size":2048*3,
    "alpha":0.2,
    "penalty_angle":20,
    "lambda":5.5


}

train_2d_to_3d.main(generalization_config)

# %% [markdown]
# ### Infer pointclouds using trained 2D Encoder and 3D Decoder models

# %% [markdown]
# Variational inferences:

# %%
from inference import inference_2d_to_3d 

generalization_config = {
    'experiment_name': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/2d_logs/variational',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'bottleneck': 512,
    "cat":13,
    'batch_size': 32,
    "loss_criterion":"variational",
    "final_layer":"variational",
    "3d_encoder_path":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/logs/model_epoch_500.pth",
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    "autoencoder_bottleneck":512,
    "autoencoder_hidden_size":256,
    "autoencoder_output_size":2048*3

}
inference_2d_to_3d.main(generalization_config)

# %% [markdown]
# Normal inferences:

# %% [markdown]
# Using L1 in the training

# %%
from inference import inference_2d_to_3d 

generalization_config = {
    'experiment_name': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/2d_logs/normal/L1',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'bottleneck': 512,
    "cat":13,
    'batch_size': 32,
    "loss_criterion":"L1",
    "final_layer":"normal",
    "3d_encoder_path":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/logs/model_epoch_500.pth",
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    "autoencoder_bottleneck":512,
    "autoencoder_hidden_size":256,
    "autoencoder_output_size":2048*3

}
inference_2d_to_3d.main(generalization_config)

# %% [markdown]
# Using L2 in the training

# %%
from inference import inference_2d_to_3d 

generalization_config = {
    'experiment_name': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/2d_logs/normal/L2',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'bottleneck': 512,
    "cat":13,
    'batch_size': 32,
    "loss_criterion":"L2",
    "final_layer":"normal",
    "3d_encoder_path":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/logs/model_epoch_500.pth",
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    "autoencoder_bottleneck":512,
    "autoencoder_hidden_size":256,
    "autoencoder_output_size":2048*3

}
inference_2d_to_3d.main(generalization_config)

# %% [markdown]
# ## 3D Autoencoder Training

# %%
from training import train_ae


    # parser.add_argument("--root", type=str, default="./data")
    # parser.add_argument("--npoints", type=int, default=2048)
    # parser.add_argument("--mpoints", type=int, default=2025)
    # parser.add_argument("--batch_size", type=int, default=16)
    # parser.add_argument("--lr", type=float, default=1e-4)
    # parser.add_argument("--weight_decay", type=float, default=1e-6)
    # parser.add_argument("--epochs", type=int, default=400)
    # parser.add_argument("--num_workers", type=int, default=4)
    # parser.add_argument("--log_dir", type=str, default="./log")

generalization_config = {
    'root': './3d-lmnet-pytorch/',
    'experiment_name': '3d_autoencoder',
    'device': 'cuda:0',  # run this on a gpu for a reasonable training time
    'is_overfit': False,
    'npoints': 2048,
    'mpoints': 2025,
    'lr': 1e-4,
    "autoencoder":"/content/3d-lmnet-pytorch/3d-lmnet-pytorch/logs/model_epoch_300.pth",
    'weight_decay': 1e-6,
    'bottleneck': 512,
    'batch_size': 32,
    'resume_ckpt': None,
    'learning_rate_model':  0.00005,
    'max_epochs': 200,  
    'num_workers': 4,
    "input_size" : 256,
    "hidden_size" : 256,
    "output_size" : 2048*3,
    'log_dir': '/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/additional_epoches',
    'print_every_n': 5,
    'visualize_every_n': 5,
}

train_ae.main(generalization_config)
# Out:
#  initial input 512 initial hidden 16 initial output 3
# Begin Training...
# initial point cloud size torch.Size([16, 3, 2048])
# tensor size after encoder torch.Size([16, 512])
# tensor size after decoder torch.Size([16, 3])
# recons size torch.Size([16, 3, 1])
# point cloud size before loss function torch.Size([16, 2048, 3])
# recons size before loss function torch.Size([16, 1, 3])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-55adbbeb75b6> in <module>
#      35 }
#      36
# ---> 37 train_ae.main(generalization_config)
#
# /content/3d-lmnet-pytorch/3d-lmnet-pytorch/training/train_ae.py in main(config)
#     104             print("recons size before loss function " + str(recons.size()))
#     105
# --> 106             loss = chamfer_loss(point_clouds, recons)
#     107
#     108            # optimizer.zero_grad()
#
# /content/3d-lmnet-pytorch/3d-lmnet-pytorch/utils/losses.py in __call__(self, y_true, y_pred)
#      27
#      28     def __call__(self, y_true, y_pred):
# ---> 29         dists_forward, _ = torch.cdist(y_true, y_pred)
#      30         dists_backward, _ = torch.cdist(y_pred, y_true)
#      31
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ### 3D Inferences

# %%
from inference import infer_3d

generalization_config = {
    "autoencoder":"/content/drive/MyDrive/3d-lmnet-pytorch/3d-lmnet-pytorch/logs/model_epoch_500.pth",
    'bottleneck': 512,
    'batch_size': 1,
    'num_workers': 4,
    "input_size" : 256,
    "hidden_size" : 256,
    "output_size" : 2048*3,
}

infer_3d.main(generalization_config)
